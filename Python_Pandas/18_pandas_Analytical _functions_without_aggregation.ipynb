# %%
import pandas as pd

df = pd.read_csv(
    './01_Data/product_prices_cleaned.csv',
    sep=','
)
df.head()
# Out:
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN                 2
# 1               ŁÓDŹ           NaN      PLN                 4
# 2  KUYAVIA-POMERANIA           NaN      PLN                 2
# 3      LOWER SILESIA           NaN      PLN                 2
# 4     WARMIA-MASURIA           NaN      PLN                 2
#
#                       product_line  value        date  \
# 0        pork ham cooked - per 1kg  21.37  2013-03-01
# 1                  bread - per 1kg    NaN  2018-02-01
# 2  barley groats sausage - per 1kg   3.55  2019-12-01
# 3       dressed chickens - per 1kg   6.14  2019-02-01
# 4    Italian head cheese - per 1kg   5.63  2002-03-01
#
#                            product  year  month  quarter
# 0        pork ham cooked - per 1kg  2013      3        1
# 1                  bread - per 1kg  2018      2        1
# 2  barley groats sausage - per 1kg  2019     12        4
# 3       dressed chickens - per 1kg  2019      2        1
# 4    Italian head cheese - per 1kg  2002      3        1

# %%
df_test = df.loc[
    (df['product'] == 'barley groats sausage - per 1kg') &
    (df['province'] == 'POLAND')
]
df_test.head()
# Out:
#      province product_types currency  product_group_id  \
# 888    POLAND           NaN      PLN                 2
# 3257   POLAND           NaN      PLN                 2
# 4384   POLAND           NaN      PLN                 2
# 4846   POLAND           NaN      PLN                 2
# 6033   POLAND           NaN      PLN                 2
#
#                          product_line  value        date  \
# 888   barley groats sausage - per 1kg   4.34  2002-06-01
# 3257  barley groats sausage - per 1kg   7.63  2012-03-01
# 4384  barley groats sausage - per 1kg   7.24  2011-08-01
# 4846  barley groats sausage - per 1kg   5.76  2008-08-01
# 6033  barley groats sausage - per 1kg   3.70  2019-02-01
#
#                               product  year  month  quarter
# 888   barley groats sausage - per 1kg  2002      6        2
# 3257  barley groats sausage - per 1kg  2012      3        1
# 4384  barley groats sausage - per 1kg  2011      8        3
# 4846  barley groats sausage - per 1kg  2008      8        3
# 6033  barley groats sausage - per 1kg  2019      2        1

# %%
df_sorted = df_test.sort_values(by=['value'], ascending=False)

# %%
df_sorted['rn'] = df_sorted.groupby(by=['product']).cumcount()

# %%
df_sorted.head()
# Out:
#       province product_types currency  product_group_id  \
# 58430   POLAND           NaN      PLN                 2
# 95878   POLAND           NaN      PLN                 2
# 27810   POLAND           NaN      PLN                 2
# 17846   POLAND           NaN      PLN                 2
# 44600   POLAND           NaN      PLN                 2
#
#                           product_line  value        date  \
# 58430  barley groats sausage - per 1kg   9.41  2019-01-01
# 95878  barley groats sausage - per 1kg   9.40  2018-08-01
# 27810  barley groats sausage - per 1kg   9.33  2018-10-01
# 17846  barley groats sausage - per 1kg   9.24  2019-10-01
# 44600  barley groats sausage - per 1kg   9.17  2018-06-01
#
#                                product  year  month  quarter  rn
# 58430  barley groats sausage - per 1kg  2019      1        1   0
# 95878  barley groats sausage - per 1kg  2018      8        3   1
# 27810  barley groats sausage - per 1kg  2018     10        4   2
# 17846  barley groats sausage - per 1kg  2019     10        4   3
# 44600  barley groats sausage - per 1kg  2018      6        2   4

# %%
df_sorted.query("rn < 10")
# Out:
#       province product_types currency  product_group_id  \
# 58430   POLAND           NaN      PLN                 2
# 95878   POLAND           NaN      PLN                 2
# 27810   POLAND           NaN      PLN                 2
# 17846   POLAND           NaN      PLN                 2
# 44600   POLAND           NaN      PLN                 2
# 26335   POLAND           NaN      PLN                 2
# 83383   POLAND           NaN      PLN                 2
# 46104   POLAND           NaN      PLN                 2
# 99474   POLAND           NaN      PLN                 2
# 79836   POLAND           NaN      PLN                 2
#
#                           product_line  value        date  \
# 58430  barley groats sausage - per 1kg   9.41  2019-01-01
# 95878  barley groats sausage - per 1kg   9.40  2018-08-01
# 27810  barley groats sausage - per 1kg   9.33  2018-10-01
# 17846  barley groats sausage - per 1kg   9.24  2019-10-01
# 44600  barley groats sausage - per 1kg   9.17  2018-06-01
# 26335  barley groats sausage - per 1kg   9.14  2019-09-01
# 83383  barley groats sausage - per 1kg   9.12  2017-11-01
# 46104  barley groats sausage - per 1kg   9.11  2018-02-01
# 99474  barley groats sausage - per 1kg   8.98  2019-07-01
# 79836  barley groats sausage - per 1kg   8.90  2018-12-01
#
#                                product  year  month  quarter  rn
# 58430  barley groats sausage - per 1kg  2019      1        1   0
# 95878  barley groats sausage - per 1kg  2018      8        3   1
# 27810  barley groats sausage - per 1kg  2018     10        4   2
# 17846  barley groats sausage - per 1kg  2019     10        4   3
# 44600  barley groats sausage - per 1kg  2018      6        2   4
# 26335  barley groats sausage - per 1kg  2019      9        3   5
# 83383  barley groats sausage - per 1kg  2017     11        4   6
# 46104  barley groats sausage - per 1kg  2018      2        1   7
# 99474  barley groats sausage - per 1kg  2019      7        3   8
# 79836  barley groats sausage - per 1kg  2018     12        4   9

# %%
df_sorted['cs'] = df_sorted.groupby(by=['product'])['value'].cumsum()
df_sorted.head()
# Out:
#       province product_types currency  product_group_id  \
# 58430   POLAND           NaN      PLN                 2
# 95878   POLAND           NaN      PLN                 2
# 27810   POLAND           NaN      PLN                 2
# 17846   POLAND           NaN      PLN                 2
# 44600   POLAND           NaN      PLN                 2
#
#                           product_line  value        date  \
# 58430  barley groats sausage - per 1kg   9.41  2019-01-01
# 95878  barley groats sausage - per 1kg   9.40  2018-08-01
# 27810  barley groats sausage - per 1kg   9.33  2018-10-01
# 17846  barley groats sausage - per 1kg   9.24  2019-10-01
# 44600  barley groats sausage - per 1kg   9.17  2018-06-01
#
#                                product  year  month  quarter  rn     cs
# 58430  barley groats sausage - per 1kg  2019      1        1   0   9.41
# 95878  barley groats sausage - per 1kg  2018      8        3   1  18.81
# 27810  barley groats sausage - per 1kg  2018     10        4   2  28.14
# 17846  barley groats sausage - per 1kg  2019     10        4   3  37.38
# 44600  barley groats sausage - per 1kg  2018      6        2   4  46.55

# %%
df_sorted = df_sorted.sort_values(by=['date'], ascending=True)

# %%
df_sorted['cummin'] = df_sorted.groupby(by=['product'])['value'].cummin()
df_sorted.head()
# Out:
#        province product_types currency  product_group_id  \
# 109105   POLAND           NaN      PLN                 2
# 63584    POLAND           NaN      PLN                 2
# 98733    POLAND           NaN      PLN                 2
# 34091    POLAND           NaN      PLN                 2
# 104713   POLAND           NaN      PLN                 2
#
#                            product_line  value        date  \
# 109105  barley groats sausage - per 1kg   3.40  1999-01-01
# 63584   barley groats sausage - per 1kg   3.59  1999-02-01
# 98733   barley groats sausage - per 1kg   3.25  1999-03-01
# 34091   barley groats sausage - per 1kg   3.41  1999-04-01
# 104713  barley groats sausage - per 1kg   3.50  1999-05-01
#
#                                 product  year  month  quarter   rn       cs  \
# 109105  barley groats sausage - per 1kg  1999      1        1  247  1506.40
# 63584   barley groats sausage - per 1kg  1999      2        1  237  1471.56
# 98733   barley groats sausage - per 1kg  1999      3        1  249  1512.94
# 34091   barley groats sausage - per 1kg  1999      4        2  245  1499.60
# 104713  barley groats sausage - per 1kg  1999      5        2  243  1492.72
#
#         cummin
# 109105    3.40
# 63584     3.40
# 98733     3.25
# 34091     3.25
# 104713    3.25

# %%
df_sorted['cummax'] = df_sorted.groupby(by=['product'])['value'].cummax()

df_sorted.head()
# Out:
#        province product_types currency  product_group_id  \
# 109105   POLAND           NaN      PLN                 2
# 63584    POLAND           NaN      PLN                 2
# 98733    POLAND           NaN      PLN                 2
# 34091    POLAND           NaN      PLN                 2
# 104713   POLAND           NaN      PLN                 2
#
#                            product_line  value        date  \
# 109105  barley groats sausage - per 1kg   3.40  1999-01-01
# 63584   barley groats sausage - per 1kg   3.59  1999-02-01
# 98733   barley groats sausage - per 1kg   3.25  1999-03-01
# 34091   barley groats sausage - per 1kg   3.41  1999-04-01
# 104713  barley groats sausage - per 1kg   3.50  1999-05-01
#
#                                 product  year  month  quarter   rn       cs  \
# 109105  barley groats sausage - per 1kg  1999      1        1  247  1506.40
# 63584   barley groats sausage - per 1kg  1999      2        1  237  1471.56
# 98733   barley groats sausage - per 1kg  1999      3        1  249  1512.94
# 34091   barley groats sausage - per 1kg  1999      4        2  245  1499.60
# 104713  barley groats sausage - per 1kg  1999      5        2  243  1492.72
#
#         cummin  cummax
# 109105    3.40    3.40
# 63584     3.40    3.59
# 98733     3.25    3.59
# 34091     3.25    3.59
# 104713    3.25    3.59
