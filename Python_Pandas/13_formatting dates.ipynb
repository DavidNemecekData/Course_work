# %% [markdown]
# # Formatting dates
#
# Load the _product_prices_cleaned.csv_ file, the _date_ column contains information about the months of value reporting.
#
# 1. What date format is it?
# 1. Change the column format to `datetime64`.
# 1. Add a new column – _month_ to the DataFrame as a way to isolate the information about the month from the _date_ column.
# 1. Add a new column – _quarter_ to the DataFrame as a way to isolate the information about the quarter from the _date_ column,
# 1. Add a new column – _year_ to the DataFrame as a way to isolate the information about the year from the _date_ column,
# 1. Using the `dt.strfime` method ([link](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.strftime.html) to the documentation), convert the  _date_ column to the _YYYY-MM-01_ format and overwrite its value; e.g.:
# ```
# df['date'] = col.dt.strftime('format')
# ```
# 1. Overwrite the _product_prices_cleaned.csv_ file. It will be used in the following sections to analyze the collection.

# %%
import pandas as pd

# %%
dates = ['2020-02', '2013-11', '2029-06']
extraction_example = pd.Series(pd.to_datetime(dates, format='%Y-%m'))
extraction_example.dt.month  # extracting months
extraction_example.dt.year  # extracting only years
# Out:
# 0    2020
# 1    2013
# 2    2029
# dtype: int32

# %%
data = pd.read_csv(
  '../../01_Data/product_prices_cleaned.csv',
  sep=';',
  encoding='UTF-8',
  decimal='.'
)

# %%
data.head()
# Out:
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN                 2
# 1               ŁÓDŹ           NaN      PLN                 4
# 2  KUYAVIA-POMERANIA           NaN      PLN                 2
# 3      LOWER SILESIA           NaN      PLN                 2
# 4     WARMIA-MASURIA           NaN      PLN                 2
#
#                       product_line  value     date  \
# 0        pork ham cooked - per 1kg  21.37   2013-3
# 1                  bread - per 1kg    NaN   2018-2
# 2  barley groats sausage - per 1kg   3.55  2019-12
# 3       dressed chickens - per 1kg   6.14   2019-2
# 4    Italian head cheese - per 1kg   5.63   2002-3
#
#                            product
# 0        pork ham cooked - per 1kg
# 1                  bread - per 1kg
# 2  barley groats sausage - per 1kg
# 3       dressed chickens - per 1kg
# 4    Italian head cheese - per 1kg

# %%
data['date'].head()
# Out:
# 0     2013-3
# 1     2018-2
# 2    2019-12
# 3     2019-2
# 4     2002-3
# Name: date, dtype: object

# %%
data['date'] = pd.to_datetime(data['date'], format='%Y-%m')

# %%
data.head()
# Out:
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN                 2
# 1               ŁÓDŹ           NaN      PLN                 4
# 2  KUYAVIA-POMERANIA           NaN      PLN                 2
# 3      LOWER SILESIA           NaN      PLN                 2
# 4     WARMIA-MASURIA           NaN      PLN                 2
#
#                       product_line  value       date  \
# 0        pork ham cooked - per 1kg  21.37 2013-03-01
# 1                  bread - per 1kg    NaN 2018-02-01
# 2  barley groats sausage - per 1kg   3.55 2019-12-01
# 3       dressed chickens - per 1kg   6.14 2019-02-01
# 4    Italian head cheese - per 1kg   5.63 2002-03-01
#
#                            product
# 0        pork ham cooked - per 1kg
# 1                  bread - per 1kg
# 2  barley groats sausage - per 1kg
# 3       dressed chickens - per 1kg
# 4    Italian head cheese - per 1kg

# %% [markdown]
# """Add a new column – month to the DataFrame as a way to isolate the information about the month from the date column.
# Add a new column – quarter to the DataFrame as a way to isolate the information about the quarter from the date column,
# Add a new column – year to the DataFrame as a way to isolate the information about the year from the date column,"""

# %%
data_year = data['date'].dt.year

# %%
data_year.head()
# Out:
# 0    2013
# 1    2018
# 2    2019
# 3    2019
# 4    2002
# Name: date, dtype: int32

# %%
data['year'] = data_year

# %%
data_month = data['date'].dt.month

# %%
data['month'] = data_month

# %%
data.head()
# Out:
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN                 2
# 1               ŁÓDŹ           NaN      PLN                 4
# 2  KUYAVIA-POMERANIA           NaN      PLN                 2
# 3      LOWER SILESIA           NaN      PLN                 2
# 4     WARMIA-MASURIA           NaN      PLN                 2
#
#                       product_line  value       date  \
# 0        pork ham cooked - per 1kg  21.37 2013-03-01
# 1                  bread - per 1kg    NaN 2018-02-01
# 2  barley groats sausage - per 1kg   3.55 2019-12-01
# 3       dressed chickens - per 1kg   6.14 2019-02-01
# 4    Italian head cheese - per 1kg   5.63 2002-03-01
#
#                            product  year  month
# 0        pork ham cooked - per 1kg  2013      3
# 1                  bread - per 1kg  2018      2
# 2  barley groats sausage - per 1kg  2019     12
# 3       dressed chickens - per 1kg  2019      2
# 4    Italian head cheese - per 1kg  2002      3

# %%
data_quarter = data['date'].dt.quarter

# %%
data_quarter.head()
# Out:
# 0    1
# 1    1
# 2    4
# 3    1
# 4    1
# Name: date, dtype: int32

# %%
data['quarter'] = data_quarter

# %%
data.head()
# Out:
#             province product_types currency  product_group_id  \
# 0       SUBCARPATHIA           NaN      PLN                 2
# 1               ŁÓDŹ           NaN      PLN                 4
# 2  KUYAVIA-POMERANIA           NaN      PLN                 2
# 3      LOWER SILESIA           NaN      PLN                 2
# 4     WARMIA-MASURIA           NaN      PLN                 2
#
#                       product_line  value       date  \
# 0        pork ham cooked - per 1kg  21.37 2013-03-01
# 1                  bread - per 1kg    NaN 2018-02-01
# 2  barley groats sausage - per 1kg   3.55 2019-12-01
# 3       dressed chickens - per 1kg   6.14 2019-02-01
# 4    Italian head cheese - per 1kg   5.63 2002-03-01
#
#                            product  year  month  quarter
# 0        pork ham cooked - per 1kg  2013      3        1
# 1                  bread - per 1kg  2018      2        1
# 2  barley groats sausage - per 1kg  2019     12        4
# 3       dressed chickens - per 1kg  2019      2        1
# 4    Italian head cheese - per 1kg  2002      3        1

# %%
data['date'] = data['date'].dt.strftime('%Y-%m-%d')

# %%
data
# Out:
#                  province                       product_types currency  \
# 0            SUBCARPATHIA                                 NaN      PLN
# 1                    ŁÓDŹ                                 NaN      PLN
# 2       KUYAVIA-POMERANIA                                 NaN      PLN
# 3           LOWER SILESIA                                 NaN      PLN
# 4          WARMIA-MASURIA                                 NaN      PLN
# ...                   ...                                 ...      ...
# 128515            SILESIA                                 NaN      PLN
# 128516            SILESIA                                 NaN      PLN
# 128517  KUYAVIA-POMERANIA                                 NaN      PLN
# 128518               ŁÓDŹ  beet sugar white, bagged - per 1kg      PLN
# 128519     WARMIA-MASURIA                                 NaN      PLN
#
#         product_group_id                       product_line  value  \
# 0                      2          pork ham cooked - per 1kg  21.37
# 1                      4                    bread - per 1kg    NaN
# 2                      2    barley groats sausage - per 1kg   3.55
# 3                      2         dressed chickens - per 1kg   6.14
# 4                      2      Italian head cheese - per 1kg   5.63
# ...                  ...                                ...    ...
# 128515                 2   smoked bacon with ribs - per 1kg  15.95
# 128516                 2    barley groats sausage - per 1kg   4.50
# 128517                 2   pork  meat (raw bacon) - per 1kg  12.15
# 128518                 3                                NaN   0.00
# 128519                 2  boneless beef (sirloin) - per 1kg  11.87
#
#               date                             product  year  month  quarter
# 0       2013-03-01           pork ham cooked - per 1kg  2013      3        1
# 1       2018-02-01                     bread - per 1kg  2018      2        1
# 2       2019-12-01     barley groats sausage - per 1kg  2019     12        4
# 3       2019-02-01          dressed chickens - per 1kg  2019      2        1
# 4       2002-03-01       Italian head cheese - per 1kg  2002      3        1
# ...            ...                                 ...   ...    ...      ...
# 128515  2015-09-01    smoked bacon with ribs - per 1kg  2015      9        3
# 128516  2004-08-01     barley groats sausage - per 1kg  2004      8        3
# 128517  2016-11-01    pork  meat (raw bacon) - per 1kg  2016     11        4
# 128518  2012-05-01  beet sugar white, bagged - per 1kg  2012      5        2
# 128519  2000-11-01   boneless beef (sirloin) - per 1kg  2000     11        4
#
# [128520 rows x 11 columns]

# %%
data.to_csv('../../01_Data/product_prices_cleaned.csv', index=False)
