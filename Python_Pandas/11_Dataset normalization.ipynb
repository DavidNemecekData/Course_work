# %% [markdown]
# # Dataset normalization
#
# In the sheets of the **dims.xlsx** file there are dictionaries for the data from the **product_prices_cleaned.csv** file. Use `merge` to normalize the data following the steps:
#
# 1. Read the contents of the **dims.xlsx** file sheets to separate `DataFrames`.
# For readability base names of frames on the names of sheets.
#
# 1. Read the data from **product_prices_cleaned.csv** file to the `df` variable.
#
# 1. Based on the **d_province** workbook, use the `id` column to add the `province_id` column to the `df` frame.
#
# 1. Based on the  **d_product** workbook, add the `product_id` column to the `df` frame.
#
# 1. From the table, extract only the columns that refer to other tables, e.g.. **product_id** and the columns **value**, **date**. Do you think this is more readable? What are potential benefits of this approach?
#
# > We will tell you how to read many workbooks at once when we discuss `openpyxl`.
#
# You can find more about database normalization at the [link](https://www.sqlshack.com/what-is-database-normalization-in-sql-server/).

# %%
import pandas as pd

# %%
data_dims_product = pd.read_excel(
    r'../../01_Data\dims.xlsx',
    sheet_name = 'd_product'
)

# %%
data_dims_province = pd.read_excel(
    r'../../01_Data\dims.xlsx',
    sheet_name = 'd_province'
)

# %%
data_dims_product_group = pd.read_excel(
    r'../../01_Data\dims.xlsx',
    sheet_name = 'd_product_group'
)

# %%
data_cleaned = pd.read_csv(
  '../../01_Data/product_prices_cleaned.csv',
  sep=';',
  encoding='UTF-8',
  decimal='.'
)

# %%
join_province = pd.merge(
    left = data_cleaned,
    right = data_dims_province,
    how='left',
    left_on=['province'],
    right_on=['province']
)

# %%
join_province
# Out:
#                  province                       product_types currency  \
# 0            SUBCARPATHIA                                 NaN      PLN
# 1                    ŁÓDŹ                                 NaN      PLN
# 2       KUYAVIA-POMERANIA                                 NaN      PLN
# 3           LOWER SILESIA                                 NaN      PLN
# 4          WARMIA-MASURIA                                 NaN      PLN
# ...                   ...                                 ...      ...
# 128515            SILESIA                                 NaN      PLN
# 128516            SILESIA                                 NaN      PLN
# 128517  KUYAVIA-POMERANIA                                 NaN      PLN
# 128518               ŁÓDŹ  beet sugar white, bagged - per 1kg      PLN
# 128519     WARMIA-MASURIA                                 NaN      PLN
#
#         product_group_id                       product_line  value     date  \
# 0                      2          pork ham cooked - per 1kg  21.37   2013-3
# 1                      4                    bread - per 1kg    NaN   2018-2
# 2                      2    barley groats sausage - per 1kg   3.55  2019-12
# 3                      2         dressed chickens - per 1kg   6.14   2019-2
# 4                      2      Italian head cheese - per 1kg   5.63   2002-3
# ...                  ...                                ...    ...      ...
# 128515                 2   smoked bacon with ribs - per 1kg  15.95   2015-9
# 128516                 2    barley groats sausage - per 1kg   4.50   2004-8
# 128517                 2   pork  meat (raw bacon) - per 1kg  12.15  2016-11
# 128518                 3                                NaN   0.00   2012-5
# 128519                 2  boneless beef (sirloin) - per 1kg  11.87  2000-11
#
#                                    product  province_id
# 0                pork ham cooked - per 1kg          8.0
# 1                          bread - per 1kg         14.0
# 2          barley groats sausage - per 1kg          2.0
# 3               dressed chickens - per 1kg          1.0
# 4            Italian head cheese - per 1kg         11.0
# ...                                    ...          ...
# 128515    smoked bacon with ribs - per 1kg         15.0
# 128516     barley groats sausage - per 1kg         15.0
# 128517    pork  meat (raw bacon) - per 1kg          2.0
# 128518  beet sugar white, bagged - per 1kg         14.0
# 128519   boneless beef (sirloin) - per 1kg         11.0
#
# [128520 rows x 9 columns]

# %%
data_dims_product
# Out:
#     product_id                                           product  \
# 0           20                         pork ham cooked - per 1kg
# 1           26                                   bread - per 1kg
# 2           10                   barley groats sausage - per 1kg
# 3           12                        dressed chickens - per 1kg
# 4           19                     Italian head cheese - per 1kg
# 5            5                       pork belly cooked - per 1kg
# 6           14  pork  with bone (center-cut pork chop) - per 1kg
# 7           27           plain mixed bread (wheat-rye) - per 1kg
# 8           30              Poznan wheat flour, bagged - per 1kg
# 9            8                  fresh non-dressed carp - per 1kg
# 10           1                  30% tomato concentrate - per 1kg
# 11           6                  smoked bacon with ribs - per 1kg
# 12           7                  haddock fillets frozen - per 1kg
# 13          21             salted herring, non-dressed - per 1kg
# 14          28          buckwheat groats roasted whole - per 1kg
# 15          17             beef with bone (rump steak) - per 1kg
# 16           2               frozen carrot and pea mix - per 1kg
# 17          22                beet sugar white, bagged - per 1kg
# 18          16                 boneless beef (sirloin) - per 1kg
# 19          29                  Masurian barley groats - per 1kg
# 20          25                 white table salt bagged - per 1kg
# 21          23                 natural chocolate plain - per 1kg
# 22          13                  pork  meat (raw bacon) - per 1kg
# 23          15          pork meat with bone (shoulder) - per 1kg
# 24           9                  Hunter's sausage dried - per 1kg
# 25           3           whole pickled cucumbers 0.9l - per 1pc.
# 26          24                     fresh chicken egs - per 1 pc.
# 27           4                       apple juice, boxed - per 1l
# 28          18                 fresh non-dressed trout - per 1kg
# 29          11         Backpacker's canned pork meat - per 300 g
#
#     product_group_id
# 0                  2
# 1                  4
# 2                  2
# 3                  2
# 4                  2
# 5                  2
# 6                  2
# 7                  4
# 8                  4
# 9                  2
# 10                 1
# 11                 2
# 12                 2
# 13                 2
# 14                 4
# 15                 2
# 16                 1
# 17                 3
# 18                 2
# 19                 4
# 20                 3
# 21                 3
# 22                 2
# 23                 2
# 24                 2
# 25                 1
# 26                 3
# 27                 1
# 28                 2
# 29                 2

# %%
data_dims_product.rename(columns={'product': 'product_line'}, inplace=True)

# %%
data_dims_product
# Out:
#     product_id                                      product_line  \
# 0           20                         pork ham cooked - per 1kg
# 1           26                                   bread - per 1kg
# 2           10                   barley groats sausage - per 1kg
# 3           12                        dressed chickens - per 1kg
# 4           19                     Italian head cheese - per 1kg
# 5            5                       pork belly cooked - per 1kg
# 6           14  pork  with bone (center-cut pork chop) - per 1kg
# 7           27           plain mixed bread (wheat-rye) - per 1kg
# 8           30              Poznan wheat flour, bagged - per 1kg
# 9            8                  fresh non-dressed carp - per 1kg
# 10           1                  30% tomato concentrate - per 1kg
# 11           6                  smoked bacon with ribs - per 1kg
# 12           7                  haddock fillets frozen - per 1kg
# 13          21             salted herring, non-dressed - per 1kg
# 14          28          buckwheat groats roasted whole - per 1kg
# 15          17             beef with bone (rump steak) - per 1kg
# 16           2               frozen carrot and pea mix - per 1kg
# 17          22                beet sugar white, bagged - per 1kg
# 18          16                 boneless beef (sirloin) - per 1kg
# 19          29                  Masurian barley groats - per 1kg
# 20          25                 white table salt bagged - per 1kg
# 21          23                 natural chocolate plain - per 1kg
# 22          13                  pork  meat (raw bacon) - per 1kg
# 23          15          pork meat with bone (shoulder) - per 1kg
# 24           9                  Hunter's sausage dried - per 1kg
# 25           3           whole pickled cucumbers 0.9l - per 1pc.
# 26          24                     fresh chicken egs - per 1 pc.
# 27           4                       apple juice, boxed - per 1l
# 28          18                 fresh non-dressed trout - per 1kg
# 29          11         Backpacker's canned pork meat - per 300 g
#
#     product_group_id
# 0                  2
# 1                  4
# 2                  2
# 3                  2
# 4                  2
# 5                  2
# 6                  2
# 7                  4
# 8                  4
# 9                  2
# 10                 1
# 11                 2
# 12                 2
# 13                 2
# 14                 4
# 15                 2
# 16                 1
# 17                 3
# 18                 2
# 19                 4
# 20                 3
# 21                 3
# 22                 2
# 23                 2
# 24                 2
# 25                 1
# 26                 3
# 27                 1
# 28                 2
# 29                 2

# %%
join_province_product = pd.merge(
    left = join_province,
    right = data_dims_product,
    how='left',
    left_on=['product_group_id'],
    right_on=['product_group_id']
)

# %%
join_province_product
# Out:
#                province product_types currency  product_group_id  \
# 0          SUBCARPATHIA           NaN      PLN                 2
# 1          SUBCARPATHIA           NaN      PLN                 2
# 2          SUBCARPATHIA           NaN      PLN                 2
# 3          SUBCARPATHIA           NaN      PLN                 2
# 4          SUBCARPATHIA           NaN      PLN                 2
# ...                 ...           ...      ...               ...
# 1482259  WARMIA-MASURIA           NaN      PLN                 2
# 1482260  WARMIA-MASURIA           NaN      PLN                 2
# 1482261  WARMIA-MASURIA           NaN      PLN                 2
# 1482262  WARMIA-MASURIA           NaN      PLN                 2
# 1482263  WARMIA-MASURIA           NaN      PLN                 2
#
#                             product_line_x  value     date  \
# 0                pork ham cooked - per 1kg  21.37   2013-3
# 1                pork ham cooked - per 1kg  21.37   2013-3
# 2                pork ham cooked - per 1kg  21.37   2013-3
# 3                pork ham cooked - per 1kg  21.37   2013-3
# 4                pork ham cooked - per 1kg  21.37   2013-3
# ...                                    ...    ...      ...
# 1482259  boneless beef (sirloin) - per 1kg  11.87  2000-11
# 1482260  boneless beef (sirloin) - per 1kg  11.87  2000-11
# 1482261  boneless beef (sirloin) - per 1kg  11.87  2000-11
# 1482262  boneless beef (sirloin) - per 1kg  11.87  2000-11
# 1482263  boneless beef (sirloin) - per 1kg  11.87  2000-11
#
#                                    product  province_id  product_id  \
# 0                pork ham cooked - per 1kg          8.0          20
# 1                pork ham cooked - per 1kg          8.0          10
# 2                pork ham cooked - per 1kg          8.0          12
# 3                pork ham cooked - per 1kg          8.0          19
# 4                pork ham cooked - per 1kg          8.0           5
# ...                                    ...          ...         ...
# 1482259  boneless beef (sirloin) - per 1kg         11.0          13
# 1482260  boneless beef (sirloin) - per 1kg         11.0          15
# 1482261  boneless beef (sirloin) - per 1kg         11.0           9
# 1482262  boneless beef (sirloin) - per 1kg         11.0          18
# 1482263  boneless beef (sirloin) - per 1kg         11.0          11
#
#                                     product_line_y
# 0                        pork ham cooked - per 1kg
# 1                  barley groats sausage - per 1kg
# 2                       dressed chickens - per 1kg
# 3                    Italian head cheese - per 1kg
# 4                      pork belly cooked - per 1kg
# ...                                            ...
# 1482259           pork  meat (raw bacon) - per 1kg
# 1482260   pork meat with bone (shoulder) - per 1kg
# 1482261           Hunter's sausage dried - per 1kg
# 1482262          fresh non-dressed trout - per 1kg
# 1482263  Backpacker's canned pork meat - per 300 g
#
# [1482264 rows x 11 columns]

# %%
# I can only get rid of duplicate columns through column selection
join_province_product[['province', 'product_types', 'currency', 'product_group_id', 'product_line_x', 'value', 'date', 'province_id', 'product_id']]
# Out:
#                province product_types currency  product_group_id  \
# 0          SUBCARPATHIA           NaN      PLN                 2
# 1          SUBCARPATHIA           NaN      PLN                 2
# 2          SUBCARPATHIA           NaN      PLN                 2
# 3          SUBCARPATHIA           NaN      PLN                 2
# 4          SUBCARPATHIA           NaN      PLN                 2
# ...                 ...           ...      ...               ...
# 1482259  WARMIA-MASURIA           NaN      PLN                 2
# 1482260  WARMIA-MASURIA           NaN      PLN                 2
# 1482261  WARMIA-MASURIA           NaN      PLN                 2
# 1482262  WARMIA-MASURIA           NaN      PLN                 2
# 1482263  WARMIA-MASURIA           NaN      PLN                 2
#
#                             product_line_x  value     date  province_id  \
# 0                pork ham cooked - per 1kg  21.37   2013-3          8.0
# 1                pork ham cooked - per 1kg  21.37   2013-3          8.0
# 2                pork ham cooked - per 1kg  21.37   2013-3          8.0
# 3                pork ham cooked - per 1kg  21.37   2013-3          8.0
# 4                pork ham cooked - per 1kg  21.37   2013-3          8.0
# ...                                    ...    ...      ...          ...
# 1482259  boneless beef (sirloin) - per 1kg  11.87  2000-11         11.0
# 1482260  boneless beef (sirloin) - per 1kg  11.87  2000-11         11.0
# 1482261  boneless beef (sirloin) - per 1kg  11.87  2000-11         11.0
# 1482262  boneless beef (sirloin) - per 1kg  11.87  2000-11         11.0
# 1482263  boneless beef (sirloin) - per 1kg  11.87  2000-11         11.0
#
#          product_id
# 0                20
# 1                10
# 2                12
# 3                19
# 4                 5
# ...             ...
# 1482259          13
# 1482260          15
# 1482261           9
# 1482262          18
# 1482263          11
#
# [1482264 rows x 9 columns]

# %%
# From the table, extract only the columns that refer to other tables, e.g.. product_id and the columns value, date. 
join_province_product[['product_id', 'currency', 'product_group_id', 'value', 'date', 'province_id']]
# Out:
#          product_id currency  product_group_id  value     date  province_id
# 0                20      PLN                 2  21.37   2013-3          8.0
# 1                10      PLN                 2  21.37   2013-3          8.0
# 2                12      PLN                 2  21.37   2013-3          8.0
# 3                19      PLN                 2  21.37   2013-3          8.0
# 4                 5      PLN                 2  21.37   2013-3          8.0
# ...             ...      ...               ...    ...      ...          ...
# 1482259          13      PLN                 2  11.87  2000-11         11.0
# 1482260          15      PLN                 2  11.87  2000-11         11.0
# 1482261           9      PLN                 2  11.87  2000-11         11.0
# 1482262          18      PLN                 2  11.87  2000-11         11.0
# 1482263          11      PLN                 2  11.87  2000-11         11.0
#
# [1482264 rows x 6 columns]
