# %% [markdown]
# # Exercise 3
#
# Using the `requests` library retrieve the current exchange rates from [https://exchangeratesapi.io/](https://exchangeratesapi.io/) and display them as a list:
#
# ```
# - <RATE 1> EUR/<CURRENCY 1>
# - <RATE 2> EUR/<CURRENCY 2>
# ...
# ```
#
# The result should be similar to:
# ```
# - 4.5066 EUR/PLN
# - 1.5319 EUR/CAD
# - 0.86308 EUR/GBP
# ...
# ```

# %%
import requests
import json

# %%
API_key = '863d612bb6d80c2690069c82e99aae75'
response = requests.get(f"https://api.exchangeratesapi.io/v1/latest?access_key={API_key}")
currency = response.json()

# %%
for rate in currency['rates']:
    print(f"{currency['rates'][rate] } EUR/{rate}")
# Out:
# 4.070612 EUR/AED
# 78.447128 EUR/AFN
# 99.920915 EUR/ALL
# 430.586244 EUR/AMD
# 2.000428 EUR/ANG
# 1002.480832 EUR/AOA
# 1053.135434 EUR/ARS
# 1.628402 EUR/AUD
# 1.994899 EUR/AWG
# 1.882094 EUR/AZN
# 1.956209 EUR/BAM
# 2.241169 EUR/BBD
# 132.637763 EUR/BDT
# 1.957272 EUR/BGN
# 0.417718 EUR/BHD
# 3206.100018 EUR/BIF
# 1.108277 EUR/BMD
# 1.443815 EUR/BND
# 7.669675 EUR/BOB
# 6.23838 EUR/BRL
# 1.109932 EUR/BSD
# 1.8600323e-05 EUR/BTC
# 93.058718 EUR/BTN
# 14.721081 EUR/BWP
# 3.63246 EUR/BYN
# 21722.22882 EUR/BYR
# 2.237368 EUR/BZD
# 1.49332 EUR/CAD
# 3158.589182 EUR/CDF
# 0.939902 EUR/CHF
# 0.036754 EUR/CLF
# 1014.161901 EUR/CLP
# 7.859788 EUR/CNY
# 7.850313 EUR/CNH
# 4573.726106 EUR/COP
# 576.025769 EUR/CRC
# 1.108277 EUR/CUC
# 29.36934 EUR/CUP
# 110.288583 EUR/CVE
# 25.039025 EUR/CZK
# 197.661374 EUR/DJF
# 7.458604 EUR/DKK
# 66.264468 EUR/DOP
# 148.391645 EUR/DZD
# 53.87929 EUR/EGP
# 16.624155 EUR/ERN
# 117.821825 EUR/ETB
# 1 EUR/EUR
# 2.43854 EUR/FJD
# 0.862817 EUR/FKP
# ...

# %%
for key, value in currency['rates'].items():
    print(key, value)
# Out:
# AED 4.057515
# AFN 78.432117
# ALL 99.559226
# AMD 428.096989
# ANG 1.990726
# AOA 1002.493965
# ARS 1050.041577
# AUD 1.63487
# AWG 1.988423
# AZN 1.879988
# BAM 1.950018
# BBD 2.230456
# BDT 132.008562
# BGN 1.952322
# BHD 0.416319
# BIF 3184.790576
# BMD 1.104679
# BND 1.439412
# BOB 7.633262
# BRL 6.232633
# BSD 1.104709
# BTC 1.8920564e-05
# BTN 92.63396
# BWP 14.641386
# BYN 3.615131
# BYR 21651.715327
# BZD 2.226667
# CAD 1.49188
# CDF 3148.33594
# CHF 0.939864
# CLF 0.036701
# CLP 1012.693167
# CNY 7.83306
# CNH 7.832066
# COP 4587.622887
# CRC 572.993154
# CUC 1.104679
# CUP 29.274003
# CVE 110.329878
# CZK 25.030048
# DJF 196.714023
# DKK 7.459485
# DOP 65.947738
# DZD 147.908867
# EGP 53.711386
# ERN 16.57019
# ETB 122.563925
# EUR 1
# FJD 2.43974
# FKP 0.860016
# GBP 0.842296
# GEL 2.97712
# GGP 0.860016
# GHS 17.376274
# GIP 0.860016
# GMD 78.43213
# GNF 9533.931316
# GTQ 8.54393
# GYD 231.111559
# HKD 8.613705
# HNL 27.428526
# HRK 7.587036
# HTG 145.646146
# ...
