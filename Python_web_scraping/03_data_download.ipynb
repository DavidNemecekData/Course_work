# %% [markdown]
# # Introduction
#
# The first step in our task is to obtain the data necessary for analysis. Since our company is in the early stages of development and does not have its own database, we intend to use publicly available resources.
#
# For this purpose, we have been recommended the website [Scrape This Site](https://www.scrapethissite.com/pages/forms/). However, before we start downloading data, it is important to carefully review the [FAQ](https://www.scrapethissite.com/faq/) section on the site. Particular attention should be paid to the restrictions on the number of requests, which is crucial for our solution.
#
# It is expected that after executing the code contained in this notebook, the `data/raw/` folder will be populated with data, which will serve as the source for the next stage of the project.

# %% [markdown]
# ## Importing Required Libraries

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import os
import json

# %%
# Specify the path to hte folder
folder_path = '../drivers'
# List all path and directories in the folder
content = os.listdir(folder_path)
# Print the content
print(content)
# chromedrive file path
file_path = '../drivers/chromedriver.exe'
# Out:
# ['chromedriver.exe']

# %% [markdown]
# ## Driver and Selenium Configuration

# %%
# Set up Service and Chrome options
service = Service(file_path)
chrome_options = Options()

# Create the WebDriver instance with service and options
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
page_source = driver.page_source
soup = BeautifulSoup(page_source, "html.parser")

# %% [markdown]
# # Fetching Website Content
#
# This section of the notebook contains code for fetching website content. To properly execute the task, consider the following steps:
# - Ensure all available data on the site has been fetched by checking if there are additional data pages.
# - Locate the data of interest on the page using `html` inspection tools.
# - Navigate between subsequent data pages using browser mechanisms or by analyzing the `url` structure.
#
# > Remember to respect the query limits specified in the `FAQ`!
#
# Save the fetched data to the folder `data/raw/hockey_teams_page_{page_number}.html`. At this stage, we are retrieving data without processing it - analysis will be performed later.
#
# To fetch the `html` content of the page, you can use `browser.page_source`. Make sure the browser tool configuration (e.g., Selenium) is ready for use.
#
# > (Optional) If there are multiple pages to fetch, use the [zfill](https://www.programiz.com/python-programming/methods/string/zfill) function to maintain order in file names by adding leading zeros to the page numbers.

# %% [markdown]
# ***Getting links***

# %%
request = requests.get("https://www.scrapethissite.com/pages/forms/?page_num=1")
request
# Out:
# <Response [200]>

# %%
result = BeautifulSoup(request.text, 'html.parser')

# %%
page_links = result.find_all("ul", class_="pagination")
links = []
for ul in page_links:
    a_tags = ul.find_all("a") 
    for a in a_tags:
        href = a.attrs['href'] 
        links.append(href)

# %%
del links[-1]

# %%
full_links = []
for link in links:
    link = "https://www.scrapethissite.com" + link
    full_links.append(link)

# %%
full_links
# Out:
# ['https://www.scrapethissite.com/pages/forms/?page_num=1',
#  'https://www.scrapethissite.com/pages/forms/?page_num=2',
#  'https://www.scrapethissite.com/pages/forms/?page_num=3',
#  'https://www.scrapethissite.com/pages/forms/?page_num=4',
#  'https://www.scrapethissite.com/pages/forms/?page_num=5',
#  'https://www.scrapethissite.com/pages/forms/?page_num=6',
#  'https://www.scrapethissite.com/pages/forms/?page_num=7',
#  'https://www.scrapethissite.com/pages/forms/?page_num=8',
#  'https://www.scrapethissite.com/pages/forms/?page_num=9',
#  'https://www.scrapethissite.com/pages/forms/?page_num=10',
#  'https://www.scrapethissite.com/pages/forms/?page_num=11',
#  'https://www.scrapethissite.com/pages/forms/?page_num=12',
#  'https://www.scrapethissite.com/pages/forms/?page_num=13',
#  'https://www.scrapethissite.com/pages/forms/?page_num=14',
#  'https://www.scrapethissite.com/pages/forms/?page_num=15',
#  'https://www.scrapethissite.com/pages/forms/?page_num=16',
#  'https://www.scrapethissite.com/pages/forms/?page_num=17',
#  'https://www.scrapethissite.com/pages/forms/?page_num=18',
#  'https://www.scrapethissite.com/pages/forms/?page_num=19',
#  'https://www.scrapethissite.com/pages/forms/?page_num=20',
#  'https://www.scrapethissite.com/pages/forms/?page_num=21',
#  'https://www.scrapethissite.com/pages/forms/?page_num=22',
#  'https://www.scrapethissite.com/pages/forms/?page_num=23',
#  'https://www.scrapethissite.com/pages/forms/?page_num=24']

# %% [markdown]
# ***Getting teams data from one page***

# %%
rows = result.find("table", class_="table").find_all('tr', class_='team')

# %%
teams = []

# %%
for row in rows:
    team_data = []
    teams_facts = row.find_all('td')
    for team_fact in teams_facts:
        data = team_fact.get_text(strip=True)
        team_data.append(data)
    teams.append(team_data)

# %%
teams
# Out:
# [['Boston Bruins', '1990', '44', '24', '', '0.55', '299', '264', '35'],
#  ['Buffalo Sabres', '1990', '31', '30', '', '0.388', '292', '278', '14'],
#  ['Calgary Flames', '1990', '46', '26', '', '0.575', '344', '263', '81'],
#  ['Chicago Blackhawks', '1990', '49', '23', '', '0.613', '284', '211', '73'],
#  ['Detroit Red Wings', '1990', '34', '38', '', '0.425', '273', '298', '-25'],
#  ['Edmonton Oilers', '1990', '37', '37', '', '0.463', '272', '272', '0'],
#  ['Hartford Whalers', '1990', '31', '38', '', '0.388', '238', '276', '-38'],
#  ['Los Angeles Kings', '1990', '46', '24', '', '0.575', '340', '254', '86'],
#  ['Minnesota North Stars',
#   '1990',
#   '27',
#   '39',
#   '',
#   '0.338',
#   '256',
#   '266',
#   '-10'],
#  ['Montreal Canadiens', '1990', '39', '30', '', '0.487', '273', '249', '24'],
#  ['New Jersey Devils', '1990', '32', '33', '', '0.4', '272', '264', '8'],
#  ['New York Islanders', '1990', '25', '45', '', '0.312', '223', '290', '-67'],
#  ['New York Rangers', '1990', '36', '31', '', '0.45', '297', '265', '32'],
#  ['Philadelphia Flyers', '1990', '33', '37', '', '0.412', '252', '267', '-15'],
#  ['Pittsburgh Penguins', '1990', '41', '33', '', '0.512', '342', '305', '37'],
#  ['Quebec Nordiques', '1990', '16', '50', '', '0.2', '236', '354', '-118'],
#  ['St. Louis Blues', '1990', '47', '22', '', '0.588', '310', '250', '60'],
#  ['Toronto Maple Leafs', '1990', '23', '46', '', '0.287', '241', '318', '-77'],
#  ['Vancouver Canucks', '1990', '28', '43', '', '0.35', '243', '315', '-72'],
#  ['Washington Capitals', '1990', '37', '36', '', '0.463', '258', '258', '0'],
#  ['Winnipeg Jets', '1990', '26', '43', '', '0.325', '260', '288', '-28'],
#  ['Boston Bruins', '1991', '36', '32', '', '0.45', '270', '275', '-5'],
#  ['Buffalo Sabres', '1991', '31', '37', '', '0.388', '289', '299', '-10'],
#  ['Calgary Flames', '1991', '31', '37', '', '0.388', '296', '305', '-9'],
#  ['Chicago Blackhawks', '1991', '36', '29', '', '0.45', '257', '236', '21']]

# %% [markdown]
# ***Getting teams data from all pages***

# %%
teams = []
for link in full_links:
    request = requests.get(link)
    result = BeautifulSoup(request.text, 'html.parser')
    rows = result.find("table", class_="table").find_all('tr', class_='team')
    for row in rows:
        team_data = []
        teams_facts = row.find_all('td')
        for team_fact in teams_facts:
            data = team_fact.get_text(strip=True)
            team_data.append(data)
        teams.append(team_data)

# %%
teams
# Out:
# [['Boston Bruins', '1990', '44', '24', '', '0.55', '299', '264', '35'],
#  ['Buffalo Sabres', '1990', '31', '30', '', '0.388', '292', '278', '14'],
#  ['Calgary Flames', '1990', '46', '26', '', '0.575', '344', '263', '81'],
#  ['Chicago Blackhawks', '1990', '49', '23', '', '0.613', '284', '211', '73'],
#  ['Detroit Red Wings', '1990', '34', '38', '', '0.425', '273', '298', '-25'],
#  ['Edmonton Oilers', '1990', '37', '37', '', '0.463', '272', '272', '0'],
#  ['Hartford Whalers', '1990', '31', '38', '', '0.388', '238', '276', '-38'],
#  ['Los Angeles Kings', '1990', '46', '24', '', '0.575', '340', '254', '86'],
#  ['Minnesota North Stars',
#   '1990',
#   '27',
#   '39',
#   '',
#   '0.338',
#   '256',
#   '266',
#   '-10'],
#  ['Montreal Canadiens', '1990', '39', '30', '', '0.487', '273', '249', '24'],
#  ['New Jersey Devils', '1990', '32', '33', '', '0.4', '272', '264', '8'],
#  ['New York Islanders', '1990', '25', '45', '', '0.312', '223', '290', '-67'],
#  ['New York Rangers', '1990', '36', '31', '', '0.45', '297', '265', '32'],
#  ['Philadelphia Flyers', '1990', '33', '37', '', '0.412', '252', '267', '-15'],
#  ['Pittsburgh Penguins', '1990', '41', '33', '', '0.512', '342', '305', '37'],
#  ['Quebec Nordiques', '1990', '16', '50', '', '0.2', '236', '354', '-118'],
#  ['St. Louis Blues', '1990', '47', '22', '', '0.588', '310', '250', '60'],
#  ['Toronto Maple Leafs', '1990', '23', '46', '', '0.287', '241', '318', '-77'],
#  ['Vancouver Canucks', '1990', '28', '43', '', '0.35', '243', '315', '-72'],
#  ['Washington Capitals', '1990', '37', '36', '', '0.463', '258', '258', '0'],
#  ['Winnipeg Jets', '1990', '26', '43', '', '0.325', '260', '288', '-28'],
#  ['Boston Bruins', '1991', '36', '32', '', '0.45', '270', '275', '-5'],
#  ['Buffalo Sabres', '1991', '31', '37', '', '0.388', '289', '299', '-10'],
#  ['Calgary Flames', '1991', '31', '37', '', '0.388', '296', '305', '-9'],
#  ['Chicago Blackhawks', '1991', '36', '29', '', '0.45', '257', '236', '21'],
#  ['Detroit Red Wings', '1991', '43', '25', '', '0.537', '320', '256', '64'],
#  ['Edmonton Oilers', '1991', '36', '34', '', '0.45', '295', '297', '-2'],
#  ['Hartford Whalers', '1991', '26', '41', '', '0.325', '247', '283', '-36'],
#  ['Los Angeles Kings', '1991', '35', '31', '', '0.438', '287', '296', '-9'],
#  ['Minnesota North Stars', '1991', '32', '42', '', '0.4', '246', '278', '-32'],
#  ['Montreal Canadiens', '1991', '41', '28', '', '0.512', '267', '207', '60'],
#  ['New Jersey Devils', '1991', '38', '31', '', '0.475', '289', '259', '30'],
#  ['New York Islanders', '1991', '34', '35', '', '0.425', '291', '299', '-8'],
#  ['New York Rangers', '1991', '50', '25', '', '0.625', '321', '246', '75'],
#  ['Philadelphia Flyers', '1991', '32', '37', '', '0.4', '252', '273', '-21'],
#  ['Pittsburgh Penguins', '1991', '39', '32', '', '0.487', '343', '308', '35'],
#  ['Quebec Nordiques', '1991', '20', '48', '', '0.25', '255', '318', '-63'],
#  ['San Jose Sharks', '1991', '17', '58', '', '0.212', '219', '359', '-140'],
#  ['St. Louis Blues', '1991', '36', '33', '', '0.45', '279', '266', '13'],
#  ['Toronto Maple Leafs', '1991', '30', '43', '', '0.375', '234', '294', '-60'],
#  ['Vancouver Canucks', '1991', '42', '26', '', '0.525', '285', '250', '35'],
#  ['Washington Capitals', '1991', '45', '27', '', '0.562', '330', '275', '55'],
#  ['Winnipeg Jets', '1991', '33', '32', '', '0.412', '251', '244', '7'],
#  ['Boston Bruins', '1992', '51', '26', '', '0.607', '332', '268', '64'],
#  ['Buffalo Sabres', '1992', '38', '36', '', '0.452', '335', '297', '38'],
#  ['Calgary Flames', '1992', '43', '30', '', '0.512', '322', '282', '40'],
#  ['Chicago Blackhawks', '1992', '47', '25', '', '0.56', '279', '230', '49'],
#  ['Detroit Red Wings', '1992', '47', '28', '', '0.56', '369', '280', '89'],
#  ['Edmonton Oilers', '1992', '26', '50', '', '0.31', '242', '337', '-95'],
#  ['Hartford Whalers', '1992', '26', '52', '', '0.31', '284', '369', '-85'],
#  ['Los Angeles Kings', '1992', '39', '35', '', '0.464', '338', '340', '-2'],
#  ['Minnesota North Stars',
#   '1992',
#   '36',
#   '38',
#   '',
#   '0.429',
#   '272',
#   '293',
#   '-21'],
#  ['Montreal Canadiens', '1992', '48', '30', '', '0.571', '326', '280', '46'],
#  ['New Jersey Devils', '1992', '40', '37', '', '0.476', '308', '299', '9'],
#  ['New York Islanders', '1992', '40', '37', '', '0.476', '335', '297', '38'],
#  ['New York Rangers', '1992', '34', '39', '', '0.405', '304', '308', '-4'],
#  ['Ottawa Senators', '1992', '10', '70', '', '0.119', '202', '395', '-193'],
#  ['Philadelphia Flyers', '1992', '36', '37', '', '0.429', '319', '319', '0'],
#  ['Pittsburgh Penguins', '1992', '56', '21', '', '0.667', '367', '268', '99'],
#  ['Quebec Nordiques', '1992', '47', '27', '', '0.56', '351', '300', '51'],
#  ['San Jose Sharks', '1992', '11', '71', '', '0.131', '218', '414', '-196'],
#  ['St. Louis Blues', '1992', '37', '36', '', '0.44', '282', '278', '4'],
#  ['Tampa Bay Lightning', '1992', '23', '54', '', '0.274', '245', '332', '-87'],
#  ['Toronto Maple Leafs', '1992', '44', '29', '', '0.524', '288', '241', '47'],
#  ['Vancouver Canucks', '1992', '46', '29', '', '0.548', '346', '278', '68'],
#  ['Washington Capitals', '1992', '43', '34', '', '0.512', '325', '286', '39'],
#  ['Winnipeg Jets', '1992', '40', '37', '', '0.476', '322', '320', '2'],
#  ['Mighty Ducks of Anaheim',
#   '1993',
#   '33',
#   '46',
#   '',
#   '0.393',
#   '229',
#   '251',
#   '-22'],
#  ['Boston Bruins', '1993', '42', '29', '', '0.5', '289', '252', '37'],
#  ['Buffalo Sabres', '1993', '43', '32', '', '0.512', '282', '218', '64'],
#  ['Calgary Flames', '1993', '42', '29', '', '0.5', '302', '256', '46'],
#  ['Chicago Blackhawks', '1993', '39', '36', '', '0.464', '254', '240', '14'],
#  ['Dallas Stars', '1993', '42', '29', '', '0.5', '286', '265', '21'],
#  ['Detroit Red Wings', '1993', '46', '30', '', '0.548', '356', '275', '81'],
#  ['Edmonton Oilers', '1993', '25', '45', '', '0.298', '261', '305', '-44'],
#  ['Florida Panthers', '1993', '33', '34', '', '0.393', '233', '233', '0'],
#  ['Hartford Whalers', '1993', '27', '48', '', '0.321', '227', '288', '-61'],
#  ['Los Angeles Kings', '1993', '27', '45', '', '0.321', '294', '322', '-28'],
#  ['Montreal Canadiens', '1993', '41', '29', '', '0.488', '283', '248', '35'],
#  ['New Jersey Devils', '1993', '47', '25', '', '0.56', '306', '220', '86'],
#  ['New York Islanders', '1993', '36', '36', '', '0.429', '282', '264', '18'],
#  ['New York Rangers', '1993', '52', '24', '', '0.619', '299', '231', '68'],
#  ['Ottawa Senators', '1993', '14', '61', '', '0.167', '201', '397', '-196'],
#  ['Philadelphia Flyers', '1993', '35', '39', '', '0.417', '294', '314', '-20'],
#  ['Pittsburgh Penguins', '1993', '44', '27', '', '0.524', '299', '285', '14'],
#  ['Quebec Nordiques', '1993', '34', '42', '', '0.405', '277', '292', '-15'],
#  ['San Jose Sharks', '1993', '33', '35', '', '0.393', '252', '265', '-13'],
#  ['St. Louis Blues', '1993', '40', '33', '', '0.476', '270', '283', '-13'],
#  ['Tampa Bay Lightning', '1993', '30', '43', '', '0.357', '224', '251', '-27'],
#  ['Toronto Maple Leafs', '1993', '43', '29', '', '0.512', '280', '243', '37'],
#  ['Vancouver Canucks', '1993', '41', '40', '', '0.488', '279', '276', '3'],
#  ['Washington Capitals', '1993', '39', '35', '', '0.464', '277', '263', '14'],
#  ['Winnipeg Jets', '1993', '24', '51', '', '0.286', '245', '344', '-99'],
#  ['Mighty Ducks of Anaheim',
#   '1994',
#   '16',
#   '27',
#   '',
#   '0.333',
#   '125',
#   '164',
#   '-39'],
#  ['Boston Bruins', '1994', '27', '18', '', '0.562', '150', '127', '23'],
#  ['Buffalo Sabres', '1994', '22', '19', '', '0.458', '130', '119', '11'],
#  ['Calgary Flames', '1994', '24', '17', '', '0.5', '163', '135', '28'],
#  ['Chicago Blackhawks', '1994', '24', '19', '', '0.5', '156', '115', '41'],
#  ['Dallas Stars', '1994', '17', '23', '', '0.354', '136', '135', '1'],
#  ['Detroit Red Wings', '1994', '33', '11', '', '0.688', '180', '117', '63'],
#  ['Edmonton Oilers', '1994', '17', '27', '', '0.354', '136', '183', '-47'],
#  ['Florida Panthers', '1994', '20', '22', '', '0.417', '115', '127', '-12'],
#  ['Hartford Whalers', '1994', '19', '24', '', '0.396', '127', '141', '-14'],
#  ['Los Angeles Kings', '1994', '16', '23', '', '0.333', '142', '174', '-32'],
#  ['Montreal Canadiens', '1994', '18', '23', '', '0.375', '125', '148', '-23'],
#  ['New Jersey Devils', '1994', '22', '18', '', '0.458', '136', '121', '15'],
#  ['New York Islanders', '1994', '15', '28', '', '0.312', '126', '158', '-32'],
#  ['New York Rangers', '1994', '22', '23', '', '0.458', '139', '134', '5'],
#  ['Ottawa Senators', '1994', '9', '34', '', '0.188', '117', '174', '-57'],
#  ['Philadelphia Flyers', '1994', '28', '16', '', '0.583', '150', '132', '18'],
#  ['Pittsburgh Penguins', '1994', '29', '16', '', '0.604', '181', '158', '23'],
#  ['Quebec Nordiques', '1994', '30', '13', '', '0.625', '185', '134', '51'],
#  ['San Jose Sharks', '1994', '19', '25', '', '0.396', '129', '161', '-32'],
#  ['St. Louis Blues', '1994', '28', '15', '', '0.583', '178', '135', '43'],
#  ['Tampa Bay Lightning', '1994', '17', '28', '', '0.354', '120', '144', '-24'],
#  ['Toronto Maple Leafs', '1994', '21', '19', '', '0.438', '135', '146', '-11'],
#  ['Vancouver Canucks', '1994', '18', '18', '', '0.375', '153', '148', '5'],
#  ['Washington Capitals', '1994', '22', '18', '', '0.458', '136', '120', '16'],
#  ['Winnipeg Jets', '1994', '16', '25', '', '0.333', '157', '177', '-20'],
#  ['Mighty Ducks of Anaheim',
#   '1995',
#   '35',
#   '39',
#   '',
#   '0.427',
#   '234',
#   '247',
#   '-13'],
#  ['Boston Bruins', '1995', '40', '31', '', '0.488', '282', '269', '13'],
#  ['Buffalo Sabres', '1995', '33', '42', '', '0.402', '247', '262', '-15'],
#  ['Calgary Flames', '1995', '34', '37', '', '0.415', '241', '240', '1'],
#  ['Chicago Blackhawks', '1995', '40', '28', '', '0.488', '273', '220', '53'],
#  ['Colorado Avalanche', '1995', '47', '25', '', '0.573', '326', '240', '86'],
#  ['Dallas Stars', '1995', '26', '42', '', '0.317', '227', '280', '-53'],
#  ['Detroit Red Wings', '1995', '62', '13', '', '0.756', '325', '181', '144'],
#  ['Edmonton Oilers', '1995', '30', '44', '', '0.366', '240', '304', '-64'],
#  ['Florida Panthers', '1995', '41', '31', '', '0.5', '254', '234', '20'],
#  ['Hartford Whalers', '1995', '34', '39', '', '0.415', '237', '259', '-22'],
#  ['Los Angeles Kings', '1995', '24', '40', '', '0.293', '256', '302', '-46'],
#  ['Montreal Canadiens', '1995', '40', '32', '', '0.488', '265', '248', '17'],
#  ['New Jersey Devils', '1995', '37', '33', '', '0.451', '215', '202', '13'],
#  ['New York Islanders', '1995', '22', '50', '', '0.268', '229', '315', '-86'],
#  ['New York Rangers', '1995', '41', '27', '', '0.5', '272', '237', '35'],
#  ['Ottawa Senators', '1995', '18', '59', '', '0.22', '191', '291', '-100'],
#  ['Philadelphia Flyers', '1995', '45', '24', '', '0.549', '282', '208', '74'],
#  ['Pittsburgh Penguins', '1995', '49', '29', '', '0.598', '362', '284', '78'],
#  ['San Jose Sharks', '1995', '20', '55', '', '0.244', '252', '357', '-105'],
#  ['St. Louis Blues', '1995', '32', '34', '', '0.39', '219', '248', '-29'],
#  ['Tampa Bay Lightning', '1995', '38', '32', '', '0.463', '238', '248', '-10'],
#  ['Toronto Maple Leafs', '1995', '34', '36', '', '0.415', '247', '252', '-5'],
#  ['Vancouver Canucks', '1995', '32', '35', '', '0.39', '278', '278', '0'],
#  ['Washington Capitals', '1995', '39', '32', '', '0.476', '234', '204', '30'],
#  ['Winnipeg Jets', '1995', '36', '40', '', '0.439', '275', '291', '-16'],
#  ['Mighty Ducks of Anaheim',
#   '1996',
#   '36',
#   '33',
#   '',
#   '0.439',
#   '245',
#   '233',
#   '12'],
#  ['Boston Bruins', '1996', '26', '47', '', '0.317', '234', '300', '-66'],
#  ['Buffalo Sabres', '1996', '40', '30', '', '0.488', '237', '208', '29'],
#  ['Calgary Flames', '1996', '32', '41', '', '0.39', '214', '239', '-25'],
#  ['Chicago Blackhawks', '1996', '34', '35', '', '0.415', '223', '210', '13'],
#  ['Colorado Avalanche', '1996', '49', '24', '', '0.598', '277', '205', '72'],
#  ['Dallas Stars', '1996', '48', '26', '', '0.585', '252', '198', '54'],
#  ['Detroit Red Wings', '1996', '38', '26', '', '0.463', '253', '197', '56'],
#  ['Edmonton Oilers', '1996', '36', '37', '', '0.439', '252', '247', '5'],
#  ['Florida Panthers', '1996', '35', '28', '', '0.427', '221', '201', '20'],
#  ['Hartford Whalers', '1996', '32', '39', '', '0.39', '226', '256', '-30'],
#  ['Los Angeles Kings', '1996', '28', '43', '', '0.341', '214', '268', '-54'],
#  ['Montreal Canadiens', '1996', '31', '36', '', '0.378', '249', '276', '-27'],
#  ['New Jersey Devils', '1996', '45', '23', '', '0.549', '231', '182', '49'],
#  ['New York Islanders', '1996', '29', '41', '', '0.354', '240', '250', '-10'],
#  ['New York Rangers', '1996', '38', '34', '', '0.463', '258', '231', '27'],
#  ['Ottawa Senators', '1996', '31', '36', '', '0.378', '226', '234', '-8'],
#  ['Philadelphia Flyers', '1996', '45', '24', '', '0.549', '274', '217', '57'],
#  ['Phoenix Coyotes', '1996', '38', '37', '', '0.463', '240', '243', '-3'],
#  ['Pittsburgh Penguins', '1996', '38', '36', '', '0.463', '285', '280', '5'],
#  ['San Jose Sharks', '1996', '27', '47', '', '0.329', '211', '278', '-67'],
#  ['St. Louis Blues', '1996', '36', '35', '', '0.439', '236', '239', '-3'],
#  ['Tampa Bay Lightning', '1996', '32', '40', '', '0.39', '217', '247', '-30'],
#  ['Toronto Maple Leafs', '1996', '30', '44', '', '0.366', '230', '273', '-43'],
#  ['Vancouver Canucks', '1996', '35', '40', '', '0.427', '257', '273', '-16'],
#  ['Washington Capitals', '1996', '33', '40', '', '0.402', '214', '231', '-17'],
#  ['Mighty Ducks of Anaheim',
#   '1997',
#   '26',
#   '43',
#   '',
#   '0.317',
#   '205',
#   '261',
#   '-56'],
#  ['Boston Bruins', '1997', '39', '30', '', '0.476', '221', '194', '27'],
#  ['Buffalo Sabres', '1997', '36', '29', '', '0.439', '211', '187', '24'],
#  ['Calgary Flames', '1997', '26', '41', '', '0.317', '217', '252', '-35'],
#  ['Carolina Hurricanes', '1997', '33', '41', '', '0.402', '200', '219', '-19'],
#  ['Chicago Blackhawks', '1997', '30', '39', '', '0.366', '192', '199', '-7'],
#  ['Colorado Avalanche', '1997', '39', '26', '', '0.476', '231', '205', '26'],
#  ['Dallas Stars', '1997', '49', '22', '', '0.598', '242', '167', '75'],
#  ['Detroit Red Wings', '1997', '44', '23', '', '0.537', '250', '196', '54'],
#  ['Edmonton Oilers', '1997', '35', '37', '', '0.427', '215', '224', '-9'],
#  ['Florida Panthers', '1997', '24', '43', '', '0.293', '203', '256', '-53'],
#  ['Los Angeles Kings', '1997', '38', '33', '', '0.463', '227', '225', '2'],
#  ['Montreal Canadiens', '1997', '37', '32', '', '0.451', '235', '208', '27'],
#  ['New Jersey Devils', '1997', '48', '23', '', '0.585', '225', '166', '59'],
#  ['New York Islanders', '1997', '30', '41', '', '0.366', '212', '225', '-13'],
#  ['New York Rangers', '1997', '25', '39', '', '0.305', '197', '231', '-34'],
#  ['Ottawa Senators', '1997', '34', '33', '', '0.415', '193', '200', '-7'],
#  ['Philadelphia Flyers', '1997', '42', '29', '', '0.512', '242', '193', '49'],
#  ['Phoenix Coyotes', '1997', '35', '35', '', '0.427', '224', '227', '-3'],
#  ['Pittsburgh Penguins', '1997', '40', '24', '', '0.488', '228', '188', '40'],
#  ['San Jose Sharks', '1997', '34', '38', '', '0.415', '210', '216', '-6'],
#  ['St. Louis Blues', '1997', '45', '29', '', '0.549', '256', '204', '52'],
#  ['Tampa Bay Lightning',
#   '1997',
#   '17',
#   '55',
#   '',
#   '0.207',
#   '151',
#   '269',
#   '-118'],
#  ['Toronto Maple Leafs', '1997', '30', '43', '', '0.366', '194', '237', '-43'],
#  ['Vancouver Canucks', '1997', '25', '43', '', '0.305', '224', '273', '-49'],
#  ['Washington Capitals', '1997', '40', '30', '', '0.488', '219', '202', '17'],
#  ['Mighty Ducks of Anaheim',
#   '1998',
#   '35',
#   '34',
#   '',
#   '0.427',
#   '215',
#   '206',
#   '9'],
#  ['Boston Bruins', '1998', '39', '30', '', '0.476', '214', '181', '33'],
#  ['Buffalo Sabres', '1998', '37', '28', '', '0.451', '207', '175', '32'],
#  ['Calgary Flames', '1998', '30', '40', '', '0.366', '211', '234', '-23'],
#  ['Carolina Hurricanes', '1998', '34', '30', '', '0.415', '210', '202', '8'],
#  ['Chicago Blackhawks', '1998', '29', '41', '', '0.354', '202', '248', '-46'],
#  ['Colorado Avalanche', '1998', '44', '28', '', '0.537', '239', '205', '34'],
#  ['Dallas Stars', '1998', '51', '19', '', '0.622', '236', '168', '68'],
#  ['Detroit Red Wings', '1998', '43', '32', '', '0.524', '245', '202', '43'],
#  ['Edmonton Oilers', '1998', '33', '37', '', '0.402', '230', '226', '4'],
#  ['Florida Panthers', '1998', '30', '34', '', '0.366', '210', '228', '-18'],
#  ['Los Angeles Kings', '1998', '32', '45', '', '0.39', '189', '222', '-33'],
#  ['Montreal Canadiens', '1998', '32', '39', '', '0.39', '184', '209', '-25'],
#  ['Nashville Predators', '1998', '28', '47', '', '0.341', '190', '261', '-71'],
#  ['New Jersey Devils', '1998', '47', '24', '', '0.573', '248', '196', '52'],
#  ['New York Islanders', '1998', '24', '48', '', '0.293', '194', '244', '-50'],
#  ['New York Rangers', '1998', '33', '38', '', '0.402', '217', '227', '-10'],
#  ['Ottawa Senators', '1998', '44', '23', '', '0.537', '239', '179', '60'],
#  ['Philadelphia Flyers', '1998', '37', '26', '', '0.451', '231', '196', '35'],
#  ['Phoenix Coyotes', '1998', '39', '31', '', '0.476', '205', '197', '8'],
#  ['Pittsburgh Penguins', '1998', '38', '30', '', '0.463', '242', '225', '17'],
#  ['San Jose Sharks', '1998', '31', '33', '', '0.378', '196', '191', '5'],
#  ['St. Louis Blues', '1998', '37', '32', '', '0.451', '237', '209', '28'],
#  ['Tampa Bay Lightning',
#   '1998',
#   '19',
#   '54',
#   '',
#   '0.232',
#   '179',
#   '292',
#   '-113'],
#  ['Toronto Maple Leafs', '1998', '45', '30', '', '0.549', '268', '231', '37'],
#  ['Vancouver Canucks', '1998', '23', '47', '', '0.28', '192', '258', '-66'],
#  ['Washington Capitals', '1998', '31', '45', '', '0.378', '200', '218', '-18'],
#  ['Mighty Ducks of Anaheim',
#   '1999',
#   '34',
#   '33',
#   '3',
#   '0.415',
#   '217',
#   '227',
#   '-10'],
#  ['Atlanta Thrashers', '1999', '14', '57', '4', '0.171', '170', '313', '-143'],
#  ['Boston Bruins', '1999', '24', '33', '6', '0.293', '210', '248', '-38'],
#  ['Buffalo Sabres', '1999', '35', '32', '4', '0.427', '213', '204', '9'],
#  ['Calgary Flames', '1999', '31', '36', '5', '0.378', '211', '256', '-45'],
#  ['Carolina Hurricanes', '1999', '37', '35', '0', '0.451', '217', '216', '1'],
#  ['Chicago Blackhawks', '1999', '33', '37', '2', '0.402', '242', '245', '-3'],
#  ['Colorado Avalanche', '1999', '42', '28', '1', '0.512', '233', '201', '32'],
#  ['Dallas Stars', '1999', '43', '23', '6', '0.524', '211', '184', '27'],
#  ['Detroit Red Wings', '1999', '48', '22', '2', '0.585', '278', '210', '68'],
#  ['Edmonton Oilers', '1999', '32', '26', '8', '0.39', '226', '212', '14'],
#  ['Florida Panthers', '1999', '43', '27', '6', '0.524', '244', '209', '35'],
#  ['Los Angeles Kings', '1999', '39', '27', '4', '0.476', '245', '228', '17'],
#  ['Montreal Canadiens', '1999', '35', '34', '4', '0.427', '196', '194', '2'],
#  ['Nashville Predators',
#   '1999',
#   '28',
#   '40',
#   '7',
#   '0.341',
#   '199',
#   '240',
#   '-41'],
#  ['New Jersey Devils', '1999', '45', '24', '5', '0.549', '251', '203', '48'],
#  ['New York Islanders', '1999', '24', '48', '1', '0.293', '194', '275', '-81'],
#  ['New York Rangers', '1999', '29', '38', '3', '0.354', '218', '246', '-28'],
#  ['Ottawa Senators', '1999', '41', '28', '2', '0.5', '244', '210', '34'],
#  ['Philadelphia Flyers', '1999', '45', '22', '3', '0.549', '237', '179', '58'],
#  ['Phoenix Coyotes', '1999', '39', '31', '4', '0.476', '232', '228', '4'],
#  ['Pittsburgh Penguins', '1999', '37', '31', '6', '0.451', '241', '236', '5'],
#  ['San Jose Sharks', '1999', '35', '30', '7', '0.427', '225', '214', '11'],
#  ['St. Louis Blues', '1999', '51', '19', '1', '0.622', '248', '165', '83'],
#  ['Tampa Bay Lightning',
#   '1999',
#   '19',
#   '47',
#   '7',
#   '0.232',
#   '204',
#   '310',
#   '-106'],
#  ['Toronto Maple Leafs', '1999', '45', '27', '3', '0.549', '246', '222', '24'],
#  ['Vancouver Canucks', '1999', '30', '29', '8', '0.366', '227', '237', '-10'],
#  ['Washington Capitals', '1999', '44', '24', '2', '0.537', '227', '194', '33'],
#  ['Mighty Ducks of Anaheim',
#   '2000',
#   '25',
#   '41',
#   '5',
#   '0.305',
#   '188',
#   '245',
#   '-57'],
#  ['Atlanta Thrashers', '2000', '23', '45', '2', '0.28', '211', '289', '-78'],
#  ['Boston Bruins', '2000', '36', '30', '8', '0.439', '227', '249', '-22'],
#  ['Buffalo Sabres', '2000', '46', '30', '1', '0.561', '218', '184', '34'],
#  ['Calgary Flames', '2000', '27', '36', '4', '0.329', '197', '236', '-39'],
#  ['Carolina Hurricanes',
#   '2000',
#   '38',
#   '32',
#   '3',
#   '0.463',
#   '212',
#   '225',
#   '-13'],
#  ['Columbus Blue Jackets',
#   '2000',
#   '28',
#   '39',
#   '6',
#   '0.341',
#   '190',
#   '233',
#   '-43'],
#  ['Chicago Blackhawks', '2000', '29', '40', '5', '0.354', '210', '246', '-36'],
#  ['Colorado Avalanche', '2000', '52', '16', '4', '0.634', '270', '192', '78'],
#  ['Dallas Stars', '2000', '48', '24', '2', '0.585', '241', '187', '54'],
#  ['Detroit Red Wings', '2000', '49', '20', '4', '0.598', '253', '202', '51'],
#  ['Edmonton Oilers', '2000', '39', '28', '3', '0.476', '243', '222', '21'],
#  ['Florida Panthers', '2000', '22', '38', '9', '0.268', '200', '246', '-46'],
#  ['Los Angeles Kings', '2000', '38', '28', '3', '0.463', '252', '228', '24'],
#  ['Minnesota Wild', '2000', '25', '39', '5', '0.305', '168', '210', '-42'],
#  ['Montreal Canadiens', '2000', '28', '40', '6', '0.341', '206', '232', '-26'],
#  ['Nashville Predators',
#   '2000',
#   '34',
#   '36',
#   '3',
#   '0.415',
#   '186',
#   '200',
#   '-14'],
#  ['New Jersey Devils', '2000', '48', '19', '3', '0.585', '295', '195', '100'],
#  ['New York Islanders', '2000', '21', '51', '3', '0.256', '185', '268', '-83'],
#  ['New York Rangers', '2000', '33', '43', '1', '0.402', '250', '290', '-40'],
#  ['Ottawa Senators', '2000', '48', '21', '4', '0.585', '274', '205', '69'],
#  ['Philadelphia Flyers', '2000', '43', '25', '3', '0.524', '240', '207', '33'],
#  ['Phoenix Coyotes', '2000', '35', '27', '3', '0.427', '214', '212', '2'],
#  ['Pittsburgh Penguins', '2000', '42', '28', '3', '0.512', '281', '256', '25'],
#  ['San Jose Sharks', '2000', '40', '27', '3', '0.488', '217', '192', '25'],
#  ['St. Louis Blues', '2000', '43', '22', '5', '0.524', '249', '195', '54'],
#  ['Tampa Bay Lightning',
#   '2000',
#   '24',
#   '47',
#   '5',
#   '0.293',
#   '201',
#   '280',
#   '-79'],
#  ['Toronto Maple Leafs', '2000', '37', '29', '5', '0.451', '232', '207', '25'],
#  ['Vancouver Canucks', '2000', '36', '28', '7', '0.439', '239', '238', '1'],
#  ['Washington Capitals', '2000', '41', '27', '4', '0.5', '233', '211', '22'],
#  ['Mighty Ducks of Anaheim',
#   '2001',
#   '29',
#   '42',
#   '3',
#   '0.354',
#   '175',
#   '198',
#   '-23'],
#  ['Atlanta Thrashers', '2001', '19', '47', '5', '0.232', '187', '288', '-101'],
#  ['Boston Bruins', '2001', '43', '24', '9', '0.524', '236', '201', '35'],
#  ['Buffalo Sabres', '2001', '35', '35', '1', '0.427', '213', '200', '13'],
#  ['Calgary Flames', '2001', '32', '35', '3', '0.39', '201', '220', '-19'],
#  ['Carolina Hurricanes', '2001', '35', '26', '5', '0.427', '217', '217', '0'],
#  ['Columbus Blue Jackets',
#   '2001',
#   '22',
#   '47',
#   '5',
#   '0.268',
#   '164',
#   '255',
#   '-91'],
#  ['Chicago Blackhawks', '2001', '41', '27', '1', '0.5', '216', '207', '9'],
#  ['Colorado Avalanche', '2001', '45', '28', '1', '0.549', '212', '169', '43'],
#  ['Dallas Stars', '2001', '36', '28', '5', '0.439', '215', '213', '2'],
#  ['Detroit Red Wings', '2001', '51', '17', '4', '0.622', '251', '187', '64'],
#  ['Edmonton Oilers', '2001', '38', '28', '4', '0.463', '205', '182', '23'],
#  ['Florida Panthers', '2001', '22', '44', '6', '0.268', '180', '250', '-70'],
#  ['Los Angeles Kings', '2001', '40', '27', '4', '0.488', '214', '190', '24'],
#  ['Minnesota Wild', '2001', '26', '35', '9', '0.317', '195', '238', '-43'],
#  ['Montreal Canadiens', '2001', '36', '31', '3', '0.439', '207', '209', '-2'],
#  ['Nashville Predators',
#   '2001',
#   '28',
#   '41',
#   '0',
#   '0.341',
#   '196',
#   '230',
#   '-34'],
#  ['New Jersey Devils', '2001', '41', '28', '4', '0.5', '205', '187', '18'],
#  ['New York Islanders', '2001', '42', '28', '4', '0.512', '239', '220', '19'],
#  ['New York Rangers', '2001', '36', '38', '4', '0.439', '227', '258', '-31'],
#  ['Ottawa Senators', '2001', '39', '27', '7', '0.476', '243', '208', '35'],
#  ['Philadelphia Flyers', '2001', '42', '27', '3', '0.512', '234', '192', '42'],
#  ['Phoenix Coyotes', '2001', '40', '27', '6', '0.488', '228', '210', '18'],
#  ['Pittsburgh Penguins',
#   '2001',
#   '28',
#   '41',
#   '5',
#   '0.341',
#   '198',
#   '249',
#   '-51'],
#  ['San Jose Sharks', '2001', '44', '27', '3', '0.537', '248', '199', '49'],
#  ['St. Louis Blues', '2001', '43', '27', '4', '0.524', '227', '188', '39'],
#  ['Tampa Bay Lightning',
#   '2001',
#   '27',
#   '40',
#   '4',
#   '0.329',
#   '178',
#   '219',
#   '-41'],
#  ['Toronto Maple Leafs', '2001', '43', '25', '4', '0.524', '249', '207', '42'],
#  ['Vancouver Canucks', '2001', '42', '30', '3', '0.512', '254', '211', '43'],
#  ['Washington Capitals',
#   '2001',
#   '36',
#   '33',
#   '2',
#   '0.439',
#   '228',
#   '240',
#   '-12'],
#  ['Mighty Ducks of Anaheim',
#   '2002',
#   '40',
#   '27',
#   '6',
#   '0.488',
#   '203',
#   '193',
#   '10'],
#  ['Atlanta Thrashers', '2002', '31', '39', '5', '0.378', '226', '284', '-58'],
#  ['Boston Bruins', '2002', '36', '31', '4', '0.439', '245', '237', '8'],
#  ['Buffalo Sabres', '2002', '27', '37', '8', '0.329', '190', '219', '-29'],
#  ['Calgary Flames', '2002', '29', '36', '4', '0.354', '186', '228', '-42'],
#  ['Carolina Hurricanes',
#   '2002',
#   '22',
#   '43',
#   '6',
#   '0.268',
#   '171',
#   '240',
#   '-69'],
#  ['Columbus Blue Jackets',
#   '2002',
#   '29',
#   '42',
#   '3',
#   '0.354',
#   '213',
#   '263',
#   '-50'],
#  ['Chicago Blackhawks', '2002', '30', '33', '6', '0.366', '207', '226', '-19'],
#  ['Colorado Avalanche', '2002', '42', '19', '8', '0.512', '251', '194', '57'],
#  ['Dallas Stars', '2002', '46', '17', '4', '0.561', '245', '169', '76'],
#  ['Detroit Red Wings', '2002', '48', '20', '4', '0.585', '269', '203', '66'],
#  ['Edmonton Oilers', '2002', '36', '26', '9', '0.439', '231', '230', '1'],
#  ['Florida Panthers', '2002', '24', '36', '9', '0.293', '176', '237', '-61'],
#  ['Los Angeles Kings', '2002', '33', '37', '6', '0.402', '203', '221', '-18'],
#  ['Minnesota Wild', '2002', '42', '29', '1', '0.512', '198', '178', '20'],
#  ['Montreal Canadiens', '2002', '30', '35', '9', '0.366', '206', '234', '-28'],
#  ['Nashville Predators',
#   '2002',
#   '27',
#   '35',
#   '7',
#   '0.329',
#   '183',
#   '206',
#   '-23'],
#  ['New Jersey Devils', '2002', '46', '20', '6', '0.561', '216', '166', '50'],
#  ['New York Islanders', '2002', '35', '34', '2', '0.427', '224', '231', '-7'],
#  ['New York Rangers', '2002', '32', '36', '4', '0.39', '210', '231', '-21'],
#  ['Ottawa Senators', '2002', '52', '21', '1', '0.634', '263', '182', '81'],
#  ['Philadelphia Flyers', '2002', '45', '20', '4', '0.549', '211', '166', '45'],
#  ['Phoenix Coyotes', '2002', '31', '35', '5', '0.378', '204', '230', '-26'],
#  ['Pittsburgh Penguins',
#   '2002',
#   '27',
#   '44',
#   '5',
#   '0.329',
#   '189',
#   '255',
#   '-66'],
#  ['San Jose Sharks', '2002', '28', '37', '8', '0.341', '214', '239', '-25'],
#  ['St. Louis Blues', '2002', '41', '24', '6', '0.5', '253', '222', '31'],
#  ['Tampa Bay Lightning', '2002', '36', '25', '5', '0.439', '219', '210', '9'],
#  ['Toronto Maple Leafs', '2002', '44', '28', '3', '0.537', '236', '208', '28'],
#  ['Vancouver Canucks', '2002', '45', '23', '1', '0.549', '264', '208', '56'],
#  ['Washington Capitals', '2002', '39', '29', '6', '0.476', '224', '220', '4'],
#  ['Mighty Ducks of Anaheim',
#   '2003',
#   '29',
#   '35',
#   '8',
#   '0.354',
#   '184',
#   '213',
#   '-29'],
#  ['Atlanta Thrashers', '2003', '33', '37', '4', '0.402', '214', '243', '-29'],
#  ['Boston Bruins', '2003', '41', '19', '7', '0.5', '209', '188', '21'],
#  ['Buffalo Sabres', '2003', '37', '34', '4', '0.451', '220', '221', '-1'],
#  ['Calgary Flames', '2003', '42', '30', '3', '0.512', '200', '176', '24'],
#  ['Carolina Hurricanes',
#   '2003',
#   '28',
#   '34',
#   '6',
#   '0.341',
#   '172',
#   '209',
#   '-37'],
#  ['Columbus Blue Jackets',
#   '2003',
#   '25',
#   '45',
#   '4',
#   '0.305',
#   '177',
#   '238',
#   '-61'],
#  ['Chicago Blackhawks', '2003', '20', '43', '8', '0.244', '188', '259', '-71'],
#  ['Colorado Avalanche', '2003', '40', '22', '7', '0.488', '236', '198', '38'],
#  ['Dallas Stars', '2003', '41', '26', '2', '0.5', '194', '175', '19'],
#  ['Detroit Red Wings', '2003', '48', '21', '2', '0.585', '255', '189', '66'],
#  ['Edmonton Oilers', '2003', '36', '29', '5', '0.439', '221', '208', '13'],
#  ['Florida Panthers', '2003', '28', '35', '4', '0.341', '188', '221', '-33'],
#  ['Los Angeles Kings', '2003', '28', '29', '9', '0.341', '205', '217', '-12'],
#  ['Minnesota Wild', '2003', '30', '29', '3', '0.366', '188', '183', '5'],
#  ['Montreal Canadiens', '2003', '41', '30', '4', '0.5', '208', '192', '16'],
#  ['Nashville Predators', '2003', '38', '29', '4', '0.463', '216', '217', '-1'],
#  ['New Jersey Devils', '2003', '43', '25', '2', '0.524', '213', '164', '49'],
#  ['New York Islanders', '2003', '38', '29', '4', '0.463', '237', '210', '27'],
#  ['New York Rangers', '2003', '27', '40', '8', '0.329', '206', '250', '-44'],
#  ['Ottawa Senators', '2003', '43', '23', '6', '0.524', '262', '189', '73'],
#  ['Philadelphia Flyers', '2003', '40', '21', '6', '0.488', '229', '186', '43'],
#  ['Phoenix Coyotes', '2003', '22', '36', '6', '0.268', '188', '245', '-57'],
#  ['Pittsburgh Penguins',
#   '2003',
#   '23',
#   '47',
#   '4',
#   '0.28',
#   '190',
#   '303',
#   '-113'],
#  ['San Jose Sharks', '2003', '43', '21', '6', '0.524', '219', '183', '36'],
#  ['St. Louis Blues', '2003', '39', '30', '2', '0.476', '191', '198', '-7'],
#  ['Tampa Bay Lightning', '2003', '46', '22', '6', '0.561', '245', '192', '53'],
#  ['Toronto Maple Leafs', '2003', '45', '24', '3', '0.549', '242', '204', '38'],
#  ['Vancouver Canucks', '2003', '43', '24', '5', '0.524', '235', '194', '41'],
#  ['Washington Capitals', '2003', '23', '46', '3', '0.28', '186', '253', '-67'],
#  ['Mighty Ducks of Anaheim',
#   '2005',
#   '43',
#   '27',
#   '12',
#   '0.524',
#   '254',
#   '229',
#   '25'],
#  ['Atlanta Thrashers', '2005', '41', '33', '8', '0.5', '281', '275', '6'],
#  ['Boston Bruins', '2005', '29', '37', '16', '0.354', '230', '266', '-36'],
#  ['Buffalo Sabres', '2005', '52', '24', '6', '0.634', '281', '239', '42'],
#  ['Calgary Flames', '2005', '46', '25', '11', '0.561', '218', '200', '18'],
#  ['Carolina Hurricanes', '2005', '52', '22', '8', '0.634', '294', '260', '34'],
#  ['Columbus Blue Jackets',
#   '2005',
#   '35',
#   '43',
#   '4',
#   '0.427',
#   '223',
#   '279',
#   '-56'],
#  ['Chicago Blackhawks',
#   '2005',
#   '26',
#   '43',
#   '13',
#   '0.317',
#   '211',
#   '285',
#   '-74'],
#  ['Colorado Avalanche', '2005', '43', '30', '9', '0.524', '283', '257', '26'],
#  ['Dallas Stars', '2005', '53', '23', '6', '0.646', '265', '218', '47'],
#  ['Detroit Red Wings', '2005', '58', '16', '8', '0.707', '305', '209', '96'],
#  ['Edmonton Oilers', '2005', '41', '28', '13', '0.5', '256', '251', '5'],
#  ['Florida Panthers', '2005', '37', '34', '11', '0.451', '240', '257', '-17'],
#  ['Los Angeles Kings', '2005', '42', '35', '5', '0.512', '249', '270', '-21'],
#  ['Minnesota Wild', '2005', '38', '36', '8', '0.463', '231', '215', '16'],
#  ['Montreal Canadiens', '2005', '42', '31', '9', '0.512', '243', '247', '-4'],
#  ['Nashville Predators', '2005', '49', '25', '8', '0.598', '259', '227', '32'],
#  ['New Jersey Devils', '2005', '46', '27', '9', '0.561', '242', '229', '13'],
#  ['New York Islanders', '2005', '36', '40', '6', '0.439', '230', '278', '-48'],
#  ['New York Rangers', '2005', '44', '26', '12', '0.537', '257', '215', '42'],
#  ['Ottawa Senators', '2005', '52', '21', '9', '0.634', '314', '211', '103'],
#  ['Philadelphia Flyers', '2005', '45', '26', '11', '0.549', '267', '259', '8'],
#  ['Phoenix Coyotes', '2005', '38', '39', '5', '0.463', '246', '271', '-25'],
#  ['Pittsburgh Penguins',
#   '2005',
#   '22',
#   '46',
#   '14',
#   '0.268',
#   '244',
#   '316',
#   '-72'],
#  ['San Jose Sharks', '2005', '44', '27', '11', '0.537', '266', '242', '24'],
#  ['St. Louis Blues', '2005', '21', '46', '15', '0.256', '197', '292', '-95'],
#  ['Tampa Bay Lightning', '2005', '43', '33', '6', '0.524', '252', '260', '-8'],
#  ['Toronto Maple Leafs', '2005', '41', '33', '8', '0.5', '257', '270', '-13'],
#  ['Vancouver Canucks', '2005', '42', '32', '8', '0.512', '256', '255', '1'],
#  ['Washington Capitals',
#   '2005',
#   '29',
#   '41',
#   '12',
#   '0.354',
#   '237',
#   '306',
#   '-69'],
#  ['Anaheim Ducks', '2006', '48', '20', '14', '0.585', '258', '208', '50'],
#  ['Atlanta Thrashers', '2006', '43', '28', '11', '0.524', '246', '245', '1'],
#  ['Boston Bruins', '2006', '35', '41', '6', '0.427', '219', '289', '-70'],
#  ['Buffalo Sabres', '2006', '53', '22', '7', '0.646', '308', '242', '66'],
#  ['Calgary Flames', '2006', '43', '29', '10', '0.524', '258', '226', '32'],
#  ['Carolina Hurricanes',
#   '2006',
#   '40',
#   '34',
#   '8',
#   '0.488',
#   '241',
#   '253',
#   '-12'],
#  ['Columbus Blue Jackets',
#   '2006',
#   '33',
#   '42',
#   '7',
#   '0.402',
#   '201',
#   '249',
#   '-48'],
#  ['Chicago Blackhawks', '2006', '31', '42', '9', '0.378', '201', '258', '-57'],
#  ['Colorado Avalanche', '2006', '44', '31', '7', '0.537', '272', '251', '21'],
#  ['Dallas Stars', '2006', '50', '25', '7', '0.61', '226', '197', '29'],
#  ['Detroit Red Wings', '2006', '50', '19', '13', '0.61', '254', '199', '55'],
#  ['Edmonton Oilers', '2006', '32', '43', '7', '0.39', '195', '248', '-53'],
#  ['Florida Panthers', '2006', '35', '31', '16', '0.427', '247', '257', '-10'],
#  ['Los Angeles Kings', '2006', '27', '41', '14', '0.329', '227', '283', '-56'],
#  ['Minnesota Wild', '2006', '48', '26', '8', '0.585', '235', '191', '44'],
#  ['Montreal Canadiens', '2006', '42', '34', '6', '0.512', '245', '256', '-11'],
#  ['Nashville Predators', '2006', '51', '23', '8', '0.622', '272', '212', '60'],
#  ['New Jersey Devils', '2006', '49', '24', '9', '0.598', '216', '201', '15'],
#  ['New York Islanders', '2006', '40', '30', '12', '0.488', '248', '240', '8'],
#  ['New York Rangers', '2006', '42', '30', '10', '0.512', '242', '216', '26'],
#  ['Ottawa Senators', '2006', '48', '25', '9', '0.585', '288', '222', '66'],
#  ['Philadelphia Flyers',
#   '2006',
#   '22',
#   '48',
#   '12',
#   '0.268',
#   '214',
#   '303',
#   '-89'],
#  ['Phoenix Coyotes', '2006', '31', '46', '5', '0.378', '216', '284', '-68'],
#  ['Pittsburgh Penguins',
#   '2006',
#   '47',
#   '24',
#   '11',
#   '0.573',
#   '277',
#   '246',
#   '31'],
#  ['San Jose Sharks', '2006', '51', '26', '5', '0.622', '258', '199', '59'],
#  ['St. Louis Blues', '2006', '34', '35', '13', '0.415', '214', '254', '-40'],
#  ['Tampa Bay Lightning', '2006', '44', '33', '5', '0.537', '253', '261', '-8'],
#  ['Toronto Maple Leafs',
#   '2006',
#   '40',
#   '31',
#   '11',
#   '0.488',
#   '258',
#   '269',
#   '-11'],
#  ['Vancouver Canucks', '2006', '49', '26', '7', '0.598', '222', '201', '21'],
#  ['Washington Capitals',
#   '2006',
#   '28',
#   '40',
#   '14',
#   '0.341',
#   '235',
#   '286',
#   '-51'],
#  ['Anaheim Ducks', '2007', '47', '27', '8', '0.573', '205', '191', '14'],
#  ['Atlanta Thrashers', '2007', '34', '40', '8', '0.415', '216', '272', '-56'],
#  ['Boston Bruins', '2007', '41', '29', '12', '0.5', '212', '222', '-10'],
#  ['Buffalo Sabres', '2007', '39', '31', '12', '0.476', '255', '242', '13'],
#  ['Calgary Flames', '2007', '42', '30', '10', '0.512', '229', '227', '2'],
#  ['Carolina Hurricanes', '2007', '43', '33', '6', '0.524', '252', '249', '3'],
#  ['Columbus Blue Jackets',
#   '2007',
#   '34',
#   '36',
#   '12',
#   '0.415',
#   '193',
#   '218',
#   '-25'],
#  ['Chicago Blackhawks', '2007', '40', '34', '8', '0.488', '239', '235', '4'],
#  ['Colorado Avalanche', '2007', '44', '31', '7', '0.537', '231', '219', '12'],
#  ['Dallas Stars', '2007', '45', '30', '7', '0.549', '242', '207', '35'],
#  ['Detroit Red Wings', '2007', '54', '21', '7', '0.659', '257', '184', '73'],
#  ['Edmonton Oilers', '2007', '41', '35', '6', '0.5', '235', '251', '-16'],
#  ['Florida Panthers', '2007', '38', '35', '9', '0.463', '216', '226', '-10'],
#  ['Los Angeles Kings', '2007', '32', '43', '7', '0.39', '231', '266', '-35'],
#  ['Minnesota Wild', '2007', '44', '28', '10', '0.537', '223', '218', '5'],
#  ['Montreal Canadiens', '2007', '47', '25', '10', '0.573', '262', '222', '40'],
#  ['Nashville Predators', '2007', '41', '32', '9', '0.5', '230', '229', '1'],
#  ['New Jersey Devils', '2007', '46', '29', '7', '0.561', '206', '197', '9'],
#  ['New York Islanders', '2007', '35', '38', '9', '0.427', '194', '243', '-49'],
#  ['New York Rangers', '2007', '42', '27', '13', '0.512', '213', '199', '14'],
#  ['Ottawa Senators', '2007', '43', '31', '8', '0.524', '261', '247', '14'],
#  ['Philadelphia Flyers',
#   '2007',
#   '42',
#   '29',
#   '11',
#   '0.512',
#   '248',
#   '233',
#   '15'],
#  ['Phoenix Coyotes', '2007', '38', '37', '7', '0.463', '214', '231', '-17'],
#  ['Pittsburgh Penguins', '2007', '47', '27', '8', '0.573', '247', '216', '31'],
#  ['San Jose Sharks', '2007', '49', '23', '10', '0.598', '222', '193', '29'],
#  ['St. Louis Blues', '2007', '33', '36', '13', '0.402', '205', '237', '-32'],
#  ['Tampa Bay Lightning',
#   '2007',
#   '31',
#   '42',
#   '9',
#   '0.378',
#   '223',
#   '267',
#   '-44'],
#  ['Toronto Maple Leafs',
#   '2007',
#   '36',
#   '35',
#   '11',
#   '0.439',
#   '231',
#   '260',
#   '-29'],
#  ['Vancouver Canucks', '2007', '39', '33', '10', '0.476', '213', '215', '-2'],
#  ['Washington Capitals', '2007', '43', '31', '8', '0.524', '242', '231', '11'],
#  ['Anaheim Ducks', '2008', '42', '33', '7', '0.512', '245', '238', '7'],
#  ['Atlanta Thrashers', '2008', '35', '41', '6', '0.427', '257', '280', '-23'],
#  ['Boston Bruins', '2008', '53', '19', '10', '0.646', '274', '196', '78'],
#  ['Buffalo Sabres', '2008', '41', '32', '9', '0.5', '250', '234', '16'],
#  ['Calgary Flames', '2008', '46', '30', '6', '0.561', '254', '248', '6'],
#  ['Carolina Hurricanes', '2008', '45', '30', '7', '0.549', '239', '226', '13'],
#  ['Columbus Blue Jackets',
#   '2008',
#   '41',
#   '31',
#   '10',
#   '0.5',
#   '226',
#   '230',
#   '-4'],
#  ['Chicago Blackhawks', '2008', '46', '24', '12', '0.561', '264', '216', '48'],
#  ['Colorado Avalanche', '2008', '32', '45', '5', '0.39', '199', '257', '-58'],
#  ['Dallas Stars', '2008', '36', '35', '11', '0.439', '230', '257', '-27'],
#  ['Detroit Red Wings', '2008', '51', '21', '10', '0.622', '295', '244', '51'],
#  ['Edmonton Oilers', '2008', '38', '35', '9', '0.463', '234', '248', '-14'],
#  ['Florida Panthers', '2008', '41', '30', '11', '0.5', '234', '231', '3'],
#  ['Los Angeles Kings', '2008', '34', '37', '11', '0.415', '207', '234', '-27'],
#  ['Minnesota Wild', '2008', '40', '33', '9', '0.488', '219', '200', '19'],
#  ['Montreal Canadiens', '2008', '41', '30', '11', '0.5', '249', '247', '2'],
#  ['Nashville Predators',
#   '2008',
#   '40',
#   '34',
#   '8',
#   '0.488',
#   '213',
#   '233',
#   '-20'],
#  ['New Jersey Devils', '2008', '51', '27', '4', '0.622', '244', '209', '35'],
#  ['New York Islanders', '2008', '26', '47', '9', '0.317', '201', '279', '-78'],
#  ['New York Rangers', '2008', '43', '30', '9', '0.524', '210', '218', '-8'],
#  ['Ottawa Senators', '2008', '36', '35', '11', '0.439', '217', '237', '-20'],
#  ['Philadelphia Flyers',
#   '2008',
#   '44',
#   '27',
#   '11',
#   '0.537',
#   '264',
#   '238',
#   '26'],
#  ['Phoenix Coyotes', '2008', '36', '39', '7', '0.439', '208', '252', '-44'],
#  ['Pittsburgh Penguins', '2008', '45', '28', '9', '0.549', '264', '239', '25'],
#  ['San Jose Sharks', '2008', '53', '18', '11', '0.646', '257', '204', '53'],
#  ['St. Louis Blues', '2008', '41', '31', '10', '0.5', '233', '233', '0'],
#  ['Tampa Bay Lightning',
#   '2008',
#   '24',
#   '40',
#   '18',
#   '0.293',
#   '210',
#   '279',
#   '-69'],
#  ['Toronto Maple Leafs',
#   '2008',
#   '34',
#   '35',
#   '13',
#   '0.415',
#   '250',
#   '293',
#   '-43'],
#  ['Vancouver Canucks', '2008', '45', '27', '10', '0.549', '246', '220', '26'],
#  ['Washington Capitals', '2008', '50', '24', '8', '0.61', '272', '245', '27'],
#  ['Anaheim Ducks', '2009', '39', '32', '11', '0.476', '238', '251', '-13'],
#  ['Atlanta Thrashers', '2009', '35', '34', '13', '0.427', '234', '256', '-22'],
#  ['Boston Bruins', '2009', '39', '30', '13', '0.476', '206', '200', '6'],
#  ['Buffalo Sabres', '2009', '45', '27', '10', '0.549', '235', '207', '28'],
#  ['Calgary Flames', '2009', '40', '32', '10', '0.488', '204', '210', '-6'],
#  ['Carolina Hurricanes',
#   '2009',
#   '35',
#   '37',
#   '10',
#   '0.427',
#   '230',
#   '256',
#   '-26'],
#  ['Columbus Blue Jackets',
#   '2009',
#   '32',
#   '35',
#   '15',
#   '0.39',
#   '216',
#   '259',
#   '-43'],
#  ['Chicago Blackhawks', '2009', '52', '22', '8', '0.634', '271', '209', '62'],
#  ['Colorado Avalanche', '2009', '43', '30', '9', '0.524', '244', '233', '11'],
#  ['Dallas Stars', '2009', '37', '31', '14', '0.451', '237', '254', '-17'],
#  ['Detroit Red Wings', '2009', '44', '24', '14', '0.537', '229', '216', '13'],
#  ['Edmonton Oilers', '2009', '27', '47', '8', '0.329', '214', '284', '-70'],
#  ['Florida Panthers', '2009', '32', '37', '13', '0.39', '208', '244', '-36'],
#  ['Los Angeles Kings', '2009', '46', '27', '9', '0.561', '241', '219', '22'],
#  ['Minnesota Wild', '2009', '38', '36', '8', '0.463', '219', '246', '-27'],
#  ['Montreal Canadiens', '2009', '39', '33', '10', '0.476', '217', '223', '-6'],
#  ['Nashville Predators', '2009', '47', '29', '6', '0.573', '225', '225', '0'],
#  ['New Jersey Devils', '2009', '48', '27', '7', '0.585', '222', '191', '31'],
#  ['New York Islanders',
#   '2009',
#   '34',
#   '37',
#   '11',
#   '0.415',
#   '222',
#   '264',
#   '-42'],
#  ['New York Rangers', '2009', '38', '33', '11', '0.463', '222', '218', '4'],
#  ['Ottawa Senators', '2009', '44', '32', '6', '0.537', '225', '238', '-13'],
#  ['Philadelphia Flyers', '2009', '41', '35', '6', '0.5', '236', '225', '11'],
#  ['Phoenix Coyotes', '2009', '50', '25', '7', '0.61', '225', '202', '23'],
#  ['Pittsburgh Penguins', '2009', '47', '28', '7', '0.573', '257', '237', '20'],
#  ['San Jose Sharks', '2009', '51', '20', '11', '0.622', '264', '215', '49'],
#  ['St. Louis Blues', '2009', '40', '32', '10', '0.488', '225', '223', '2'],
#  ['Tampa Bay Lightning',
#   '2009',
#   '34',
#   '36',
#   '12',
#   '0.415',
#   '217',
#   '260',
#   '-43'],
#  ['Toronto Maple Leafs',
#   '2009',
#   '30',
#   '38',
#   '14',
#   '0.366',
#   '214',
#   '267',
#   '-53'],
#  ['Vancouver Canucks', '2009', '49', '28', '5', '0.598', '272', '222', '50'],
#  ['Washington Capitals',
#   '2009',
#   '54',
#   '15',
#   '13',
#   '0.659',
#   '318',
#   '233',
#   '85'],
#  ['Anaheim Ducks', '2010', '47', '30', '5', '0.573', '239', '235', '4'],
#  ['Atlanta Thrashers', '2010', '34', '36', '12', '0.415', '223', '269', '-46'],
#  ['Boston Bruins', '2010', '46', '25', '11', '0.561', '246', '195', '51'],
#  ['Buffalo Sabres', '2010', '43', '29', '10', '0.524', '245', '229', '16'],
#  ['Calgary Flames', '2010', '41', '29', '12', '0.5', '250', '237', '13'],
#  ['Carolina Hurricanes',
#   '2010',
#   '40',
#   '31',
#   '11',
#   '0.488',
#   '236',
#   '239',
#   '-3'],
#  ['Columbus Blue Jackets',
#   '2010',
#   '34',
#   '35',
#   '13',
#   '0.415',
#   '215',
#   '258',
#   '-43'],
#  ['Chicago Blackhawks', '2010', '44', '29', '9', '0.537', '258', '225', '33'],
#  ['Colorado Avalanche', '2010', '30', '44', '8', '0.366', '227', '288', '-61'],
#  ['Dallas Stars', '2010', '42', '29', '11', '0.512', '227', '233', '-6'],
#  ['Detroit Red Wings', '2010', '47', '25', '10', '0.573', '261', '241', '20'],
#  ['Edmonton Oilers', '2010', '25', '45', '12', '0.305', '193', '269', '-76'],
#  ['Florida Panthers', '2010', '30', '40', '12', '0.366', '195', '229', '-34'],
#  ['Los Angeles Kings', '2010', '46', '30', '6', '0.561', '219', '198', '21'],
#  ['Minnesota Wild', '2010', '39', '35', '8', '0.476', '206', '233', '-27'],
#  ['Montreal Canadiens', '2010', '44', '30', '8', '0.537', '216', '209', '7'],
#  ['Nashville Predators',
#   '2010',
#   '44',
#   '27',
#   '11',
#   '0.537',
#   '219',
#   '194',
#   '25'],
#  ['New Jersey Devils', '2010', '38', '39', '5', '0.463', '174', '209', '-35'],
#  ['New York Islanders',
#   '2010',
#   '30',
#   '39',
#   '13',
#   '0.366',
#   '229',
#   '264',
#   '-35'],
#  ['New York Rangers', '2010', '44', '33', '5', '0.537', '233', '198', '35'],
#  ['Ottawa Senators', '2010', '32', '40', '10', '0.39', '192', '250', '-58'],
#  ['Philadelphia Flyers',
#   '2010',
#   '47',
#   '23',
#   '12',
#   '0.573',
#   '259',
#   '223',
#   '36'],
#  ['Phoenix Coyotes', '2010', '43', '26', '13', '0.524', '231', '226', '5'],
#  ['Pittsburgh Penguins', '2010', '49', '25', '8', '0.598', '238', '199', '39'],
#  ['San Jose Sharks', '2010', '48', '25', '9', '0.585', '248', '213', '35'],
#  ['St. Louis Blues', '2010', '38', '33', '11', '0.463', '240', '234', '6'],
#  ['Tampa Bay Lightning', '2010', '46', '25', '11', '0.561', '247', '240', '7'],
#  ['Toronto Maple Leafs',
#   '2010',
#   '37',
#   '34',
#   '11',
#   '0.451',
#   '218',
#   '251',
#   '-33'],
#  ['Vancouver Canucks', '2010', '54', '19', '9', '0.659', '262', '185', '77'],
#  ['Washington Capitals',
#   '2010',
#   '48',
#   '23',
#   '11',
#   '0.585',
#   '224',
#   '197',
#   '27'],
#  ['Anaheim Ducks', '2011', '34', '36', '12', '0.415', '204', '231', '-27'],
#  ['Boston Bruins', '2011', '49', '29', '4', '0.598', '269', '202', '67'],
#  ['Buffalo Sabres', '2011', '39', '32', '11', '0.476', '218', '230', '-12'],
#  ['Calgary Flames', '2011', '37', '29', '16', '0.451', '202', '226', '-24'],
#  ['Carolina Hurricanes',
#   '2011',
#   '33',
#   '33',
#   '16',
#   '0.402',
#   '213',
#   '243',
#   '-30'],
#  ['Columbus Blue Jackets',
#   '2011',
#   '29',
#   '46',
#   '7',
#   '0.354',
#   '202',
#   '262',
#   '-60'],
#  ['Chicago Blackhawks', '2011', '45', '26', '11', '0.549', '248', '238', '10'],
#  ['Colorado Avalanche', '2011', '41', '35', '6', '0.5', '208', '220', '-12'],
#  ['Dallas Stars', '2011', '42', '35', '5', '0.512', '211', '222', '-11'],
#  ['Detroit Red Wings', '2011', '48', '28', '6', '0.585', '248', '203', '45'],
#  ['Edmonton Oilers', '2011', '32', '40', '10', '0.39', '212', '239', '-27'],
#  ['Florida Panthers', '2011', '38', '26', '18', '0.463', '203', '227', '-24'],
#  ['Los Angeles Kings', '2011', '40', '27', '15', '0.488', '194', '179', '15'],
#  ['Minnesota Wild', '2011', '35', '36', '11', '0.427', '177', '226', '-49'],
#  ['Montreal Canadiens',
#   '2011',
#   '31',
#   '35',
#   '16',
#   '0.378',
#   '212',
#   '226',
#   '-14'],
#  ['Nashville Predators', '2011', '48', '26', '8', '0.585', '237', '210', '27'],
#  ['New Jersey Devils', '2011', '48', '28', '6', '0.585', '228', '209', '19'],
#  ['New York Islanders',
#   '2011',
#   '34',
#   '37',
#   '11',
#   '0.415',
#   '203',
#   '255',
#   '-52'],
#  ['New York Rangers', '2011', '51', '24', '7', '0.622', '226', '187', '39'],
#  ['Ottawa Senators', '2011', '41', '31', '10', '0.5', '249', '240', '9'],
#  ['Philadelphia Flyers', '2011', '47', '26', '9', '0.573', '264', '232', '32'],
#  ['Phoenix Coyotes', '2011', '42', '27', '13', '0.512', '216', '204', '12'],
#  ['Pittsburgh Penguins', '2011', '51', '25', '6', '0.622', '282', '221', '61'],
#  ['San Jose Sharks', '2011', '43', '29', '10', '0.524', '228', '210', '18'],
#  ['St. Louis Blues', '2011', '49', '22', '11', '0.598', '210', '165', '45'],
#  ['Tampa Bay Lightning',
#   '2011',
#   '38',
#   '36',
#   '8',
#   '0.463',
#   '235',
#   '281',
#   '-46'],
#  ['Toronto Maple Leafs',
#   '2011',
#   '35',
#   '37',
#   '10',
#   '0.427',
#   '231',
#   '264',
#   '-33'],
#  ['Vancouver Canucks', '2011', '51', '22', '9', '0.622', '249', '198', '51'],
#  ['Washington Capitals', '2011', '42', '32', '8', '0.512', '222', '230', '-8'],
#  ['Winnipeg Jets', '2011', '37', '35', '10', '0.451', '225', '246', '-21']]

# %% [markdown]
# ***Data to JSON conversion***

# %%
columns = ["Team Name", "Year", "Wins", "Losses", "OT Losses", "Win %", "Goals For (GF)", "Goals Against (GA)", "+ / -"]

# %%
teams_json = []
for team in teams:
    team_dict = dict(zip(columns, team))
    teams_json.append(team_dict)

# %%
teams_json
# Out:
# [{'Team Name': 'Boston Bruins',
#   'Year': '1990',
#   'Wins': '44',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.55',
#   'Goals For (GF)': '299',
#   'Goals Against (GA)': '264',
#   '+ / -': '35'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1990',
#   'Wins': '31',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.388',
#   'Goals For (GF)': '292',
#   'Goals Against (GA)': '278',
#   '+ / -': '14'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1990',
#   'Wins': '46',
#   'Losses': '26',
#   'OT Losses': '',
#   'Win %': '0.575',
#   'Goals For (GF)': '344',
#   'Goals Against (GA)': '263',
#   '+ / -': '81'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1990',
#   'Wins': '49',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.613',
#   'Goals For (GF)': '284',
#   'Goals Against (GA)': '211',
#   '+ / -': '73'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1990',
#   'Wins': '34',
#   'Losses': '38',
#   'OT Losses': '',
#   'Win %': '0.425',
#   'Goals For (GF)': '273',
#   'Goals Against (GA)': '298',
#   '+ / -': '-25'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1990',
#   'Wins': '37',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '272',
#   'Goals Against (GA)': '272',
#   '+ / -': '0'},
#  {'Team Name': 'Hartford Whalers',
#   'Year': '1990',
#   'Wins': '31',
#   'Losses': '38',
#   'OT Losses': '',
#   'Win %': '0.388',
#   'Goals For (GF)': '238',
#   'Goals Against (GA)': '276',
#   '+ / -': '-38'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1990',
#   'Wins': '46',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.575',
#   'Goals For (GF)': '340',
#   'Goals Against (GA)': '254',
#   '+ / -': '86'},
#  {'Team Name': 'Minnesota North Stars',
#   'Year': '1990',
#   'Wins': '27',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.338',
#   'Goals For (GF)': '256',
#   'Goals Against (GA)': '266',
#   '+ / -': '-10'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1990',
#   'Wins': '39',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.487',
#   'Goals For (GF)': '273',
#   'Goals Against (GA)': '249',
#   '+ / -': '24'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1990',
#   'Wins': '32',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.4',
#   'Goals For (GF)': '272',
#   'Goals Against (GA)': '264',
#   '+ / -': '8'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1990',
#   'Wins': '25',
#   'Losses': '45',
#   'OT Losses': '',
#   'Win %': '0.312',
#   'Goals For (GF)': '223',
#   'Goals Against (GA)': '290',
#   '+ / -': '-67'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1990',
#   'Wins': '36',
#   'Losses': '31',
#   'OT Losses': '',
#   'Win %': '0.45',
#   'Goals For (GF)': '297',
#   'Goals Against (GA)': '265',
#   '+ / -': '32'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1990',
#   'Wins': '33',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.412',
#   'Goals For (GF)': '252',
#   'Goals Against (GA)': '267',
#   '+ / -': '-15'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1990',
#   'Wins': '41',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.512',
#   'Goals For (GF)': '342',
#   'Goals Against (GA)': '305',
#   '+ / -': '37'},
#  {'Team Name': 'Quebec Nordiques',
#   'Year': '1990',
#   'Wins': '16',
#   'Losses': '50',
#   'OT Losses': '',
#   'Win %': '0.2',
#   'Goals For (GF)': '236',
#   'Goals Against (GA)': '354',
#   '+ / -': '-118'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1990',
#   'Wins': '47',
#   'Losses': '22',
#   'OT Losses': '',
#   'Win %': '0.588',
#   'Goals For (GF)': '310',
#   'Goals Against (GA)': '250',
#   '+ / -': '60'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1990',
#   'Wins': '23',
#   'Losses': '46',
#   'OT Losses': '',
#   'Win %': '0.287',
#   'Goals For (GF)': '241',
#   'Goals Against (GA)': '318',
#   '+ / -': '-77'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1990',
#   'Wins': '28',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.35',
#   'Goals For (GF)': '243',
#   'Goals Against (GA)': '315',
#   '+ / -': '-72'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1990',
#   'Wins': '37',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '258',
#   'Goals Against (GA)': '258',
#   '+ / -': '0'},
#  {'Team Name': 'Winnipeg Jets',
#   'Year': '1990',
#   'Wins': '26',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.325',
#   'Goals For (GF)': '260',
#   'Goals Against (GA)': '288',
#   '+ / -': '-28'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1991',
#   'Wins': '36',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.45',
#   'Goals For (GF)': '270',
#   'Goals Against (GA)': '275',
#   '+ / -': '-5'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1991',
#   'Wins': '31',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.388',
#   'Goals For (GF)': '289',
#   'Goals Against (GA)': '299',
#   '+ / -': '-10'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1991',
#   'Wins': '31',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.388',
#   'Goals For (GF)': '296',
#   'Goals Against (GA)': '305',
#   '+ / -': '-9'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1991',
#   'Wins': '36',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.45',
#   'Goals For (GF)': '257',
#   'Goals Against (GA)': '236',
#   '+ / -': '21'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1991',
#   'Wins': '43',
#   'Losses': '25',
#   'OT Losses': '',
#   'Win %': '0.537',
#   'Goals For (GF)': '320',
#   'Goals Against (GA)': '256',
#   '+ / -': '64'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1991',
#   'Wins': '36',
#   'Losses': '34',
#   'OT Losses': '',
#   'Win %': '0.45',
#   'Goals For (GF)': '295',
#   'Goals Against (GA)': '297',
#   '+ / -': '-2'},
#  {'Team Name': 'Hartford Whalers',
#   'Year': '1991',
#   'Wins': '26',
#   'Losses': '41',
#   'OT Losses': '',
#   'Win %': '0.325',
#   'Goals For (GF)': '247',
#   'Goals Against (GA)': '283',
#   '+ / -': '-36'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1991',
#   'Wins': '35',
#   'Losses': '31',
#   'OT Losses': '',
#   'Win %': '0.438',
#   'Goals For (GF)': '287',
#   'Goals Against (GA)': '296',
#   '+ / -': '-9'},
#  {'Team Name': 'Minnesota North Stars',
#   'Year': '1991',
#   'Wins': '32',
#   'Losses': '42',
#   'OT Losses': '',
#   'Win %': '0.4',
#   'Goals For (GF)': '246',
#   'Goals Against (GA)': '278',
#   '+ / -': '-32'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1991',
#   'Wins': '41',
#   'Losses': '28',
#   'OT Losses': '',
#   'Win %': '0.512',
#   'Goals For (GF)': '267',
#   'Goals Against (GA)': '207',
#   '+ / -': '60'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1991',
#   'Wins': '38',
#   'Losses': '31',
#   'OT Losses': '',
#   'Win %': '0.475',
#   'Goals For (GF)': '289',
#   'Goals Against (GA)': '259',
#   '+ / -': '30'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1991',
#   'Wins': '34',
#   'Losses': '35',
#   'OT Losses': '',
#   'Win %': '0.425',
#   'Goals For (GF)': '291',
#   'Goals Against (GA)': '299',
#   '+ / -': '-8'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1991',
#   'Wins': '50',
#   'Losses': '25',
#   'OT Losses': '',
#   'Win %': '0.625',
#   'Goals For (GF)': '321',
#   'Goals Against (GA)': '246',
#   '+ / -': '75'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1991',
#   'Wins': '32',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.4',
#   'Goals For (GF)': '252',
#   'Goals Against (GA)': '273',
#   '+ / -': '-21'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1991',
#   'Wins': '39',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.487',
#   'Goals For (GF)': '343',
#   'Goals Against (GA)': '308',
#   '+ / -': '35'},
#  {'Team Name': 'Quebec Nordiques',
#   'Year': '1991',
#   'Wins': '20',
#   'Losses': '48',
#   'OT Losses': '',
#   'Win %': '0.25',
#   'Goals For (GF)': '255',
#   'Goals Against (GA)': '318',
#   '+ / -': '-63'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '1991',
#   'Wins': '17',
#   'Losses': '58',
#   'OT Losses': '',
#   'Win %': '0.212',
#   'Goals For (GF)': '219',
#   'Goals Against (GA)': '359',
#   '+ / -': '-140'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1991',
#   'Wins': '36',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.45',
#   'Goals For (GF)': '279',
#   'Goals Against (GA)': '266',
#   '+ / -': '13'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1991',
#   'Wins': '30',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.375',
#   'Goals For (GF)': '234',
#   'Goals Against (GA)': '294',
#   '+ / -': '-60'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1991',
#   'Wins': '42',
#   'Losses': '26',
#   'OT Losses': '',
#   'Win %': '0.525',
#   'Goals For (GF)': '285',
#   'Goals Against (GA)': '250',
#   '+ / -': '35'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1991',
#   'Wins': '45',
#   'Losses': '27',
#   'OT Losses': '',
#   'Win %': '0.562',
#   'Goals For (GF)': '330',
#   'Goals Against (GA)': '275',
#   '+ / -': '55'},
#  {'Team Name': 'Winnipeg Jets',
#   'Year': '1991',
#   'Wins': '33',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.412',
#   'Goals For (GF)': '251',
#   'Goals Against (GA)': '244',
#   '+ / -': '7'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1992',
#   'Wins': '51',
#   'Losses': '26',
#   'OT Losses': '',
#   'Win %': '0.607',
#   'Goals For (GF)': '332',
#   'Goals Against (GA)': '268',
#   '+ / -': '64'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1992',
#   'Wins': '38',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.452',
#   'Goals For (GF)': '335',
#   'Goals Against (GA)': '297',
#   '+ / -': '38'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1992',
#   'Wins': '43',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.512',
#   'Goals For (GF)': '322',
#   'Goals Against (GA)': '282',
#   '+ / -': '40'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1992',
#   'Wins': '47',
#   'Losses': '25',
#   'OT Losses': '',
#   'Win %': '0.56',
#   'Goals For (GF)': '279',
#   'Goals Against (GA)': '230',
#   '+ / -': '49'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1992',
#   'Wins': '47',
#   'Losses': '28',
#   'OT Losses': '',
#   'Win %': '0.56',
#   'Goals For (GF)': '369',
#   'Goals Against (GA)': '280',
#   '+ / -': '89'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1992',
#   'Wins': '26',
#   'Losses': '50',
#   'OT Losses': '',
#   'Win %': '0.31',
#   'Goals For (GF)': '242',
#   'Goals Against (GA)': '337',
#   '+ / -': '-95'},
#  {'Team Name': 'Hartford Whalers',
#   'Year': '1992',
#   'Wins': '26',
#   'Losses': '52',
#   'OT Losses': '',
#   'Win %': '0.31',
#   'Goals For (GF)': '284',
#   'Goals Against (GA)': '369',
#   '+ / -': '-85'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1992',
#   'Wins': '39',
#   'Losses': '35',
#   'OT Losses': '',
#   'Win %': '0.464',
#   'Goals For (GF)': '338',
#   'Goals Against (GA)': '340',
#   '+ / -': '-2'},
#  {'Team Name': 'Minnesota North Stars',
#   'Year': '1992',
#   'Wins': '36',
#   'Losses': '38',
#   'OT Losses': '',
#   'Win %': '0.429',
#   'Goals For (GF)': '272',
#   'Goals Against (GA)': '293',
#   '+ / -': '-21'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1992',
#   'Wins': '48',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.571',
#   'Goals For (GF)': '326',
#   'Goals Against (GA)': '280',
#   '+ / -': '46'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1992',
#   'Wins': '40',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '308',
#   'Goals Against (GA)': '299',
#   '+ / -': '9'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1992',
#   'Wins': '40',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '335',
#   'Goals Against (GA)': '297',
#   '+ / -': '38'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1992',
#   'Wins': '34',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.405',
#   'Goals For (GF)': '304',
#   'Goals Against (GA)': '308',
#   '+ / -': '-4'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '1992',
#   'Wins': '10',
#   'Losses': '70',
#   'OT Losses': '',
#   'Win %': '0.119',
#   'Goals For (GF)': '202',
#   'Goals Against (GA)': '395',
#   '+ / -': '-193'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1992',
#   'Wins': '36',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.429',
#   'Goals For (GF)': '319',
#   'Goals Against (GA)': '319',
#   '+ / -': '0'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1992',
#   'Wins': '56',
#   'Losses': '21',
#   'OT Losses': '',
#   'Win %': '0.667',
#   'Goals For (GF)': '367',
#   'Goals Against (GA)': '268',
#   '+ / -': '99'},
#  {'Team Name': 'Quebec Nordiques',
#   'Year': '1992',
#   'Wins': '47',
#   'Losses': '27',
#   'OT Losses': '',
#   'Win %': '0.56',
#   'Goals For (GF)': '351',
#   'Goals Against (GA)': '300',
#   '+ / -': '51'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '1992',
#   'Wins': '11',
#   'Losses': '71',
#   'OT Losses': '',
#   'Win %': '0.131',
#   'Goals For (GF)': '218',
#   'Goals Against (GA)': '414',
#   '+ / -': '-196'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1992',
#   'Wins': '37',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.44',
#   'Goals For (GF)': '282',
#   'Goals Against (GA)': '278',
#   '+ / -': '4'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '1992',
#   'Wins': '23',
#   'Losses': '54',
#   'OT Losses': '',
#   'Win %': '0.274',
#   'Goals For (GF)': '245',
#   'Goals Against (GA)': '332',
#   '+ / -': '-87'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1992',
#   'Wins': '44',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.524',
#   'Goals For (GF)': '288',
#   'Goals Against (GA)': '241',
#   '+ / -': '47'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1992',
#   'Wins': '46',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.548',
#   'Goals For (GF)': '346',
#   'Goals Against (GA)': '278',
#   '+ / -': '68'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1992',
#   'Wins': '43',
#   'Losses': '34',
#   'OT Losses': '',
#   'Win %': '0.512',
#   'Goals For (GF)': '325',
#   'Goals Against (GA)': '286',
#   '+ / -': '39'},
#  {'Team Name': 'Winnipeg Jets',
#   'Year': '1992',
#   'Wins': '40',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '322',
#   'Goals Against (GA)': '320',
#   '+ / -': '2'},
#  {'Team Name': 'Mighty Ducks of Anaheim',
#   'Year': '1993',
#   'Wins': '33',
#   'Losses': '46',
#   'OT Losses': '',
#   'Win %': '0.393',
#   'Goals For (GF)': '229',
#   'Goals Against (GA)': '251',
#   '+ / -': '-22'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1993',
#   'Wins': '42',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.5',
#   'Goals For (GF)': '289',
#   'Goals Against (GA)': '252',
#   '+ / -': '37'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1993',
#   'Wins': '43',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.512',
#   'Goals For (GF)': '282',
#   'Goals Against (GA)': '218',
#   '+ / -': '64'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1993',
#   'Wins': '42',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.5',
#   'Goals For (GF)': '302',
#   'Goals Against (GA)': '256',
#   '+ / -': '46'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1993',
#   'Wins': '39',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.464',
#   'Goals For (GF)': '254',
#   'Goals Against (GA)': '240',
#   '+ / -': '14'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '1993',
#   'Wins': '42',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.5',
#   'Goals For (GF)': '286',
#   'Goals Against (GA)': '265',
#   '+ / -': '21'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1993',
#   'Wins': '46',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.548',
#   'Goals For (GF)': '356',
#   'Goals Against (GA)': '275',
#   '+ / -': '81'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1993',
#   'Wins': '25',
#   'Losses': '45',
#   'OT Losses': '',
#   'Win %': '0.298',
#   'Goals For (GF)': '261',
#   'Goals Against (GA)': '305',
#   '+ / -': '-44'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '1993',
#   'Wins': '33',
#   'Losses': '34',
#   'OT Losses': '',
#   'Win %': '0.393',
#   'Goals For (GF)': '233',
#   'Goals Against (GA)': '233',
#   '+ / -': '0'},
#  {'Team Name': 'Hartford Whalers',
#   'Year': '1993',
#   'Wins': '27',
#   'Losses': '48',
#   'OT Losses': '',
#   'Win %': '0.321',
#   'Goals For (GF)': '227',
#   'Goals Against (GA)': '288',
#   '+ / -': '-61'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1993',
#   'Wins': '27',
#   'Losses': '45',
#   'OT Losses': '',
#   'Win %': '0.321',
#   'Goals For (GF)': '294',
#   'Goals Against (GA)': '322',
#   '+ / -': '-28'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1993',
#   'Wins': '41',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.488',
#   'Goals For (GF)': '283',
#   'Goals Against (GA)': '248',
#   '+ / -': '35'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1993',
#   'Wins': '47',
#   'Losses': '25',
#   'OT Losses': '',
#   'Win %': '0.56',
#   'Goals For (GF)': '306',
#   'Goals Against (GA)': '220',
#   '+ / -': '86'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1993',
#   'Wins': '36',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.429',
#   'Goals For (GF)': '282',
#   'Goals Against (GA)': '264',
#   '+ / -': '18'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1993',
#   'Wins': '52',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.619',
#   'Goals For (GF)': '299',
#   'Goals Against (GA)': '231',
#   '+ / -': '68'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '1993',
#   'Wins': '14',
#   'Losses': '61',
#   'OT Losses': '',
#   'Win %': '0.167',
#   'Goals For (GF)': '201',
#   'Goals Against (GA)': '397',
#   '+ / -': '-196'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1993',
#   'Wins': '35',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.417',
#   'Goals For (GF)': '294',
#   'Goals Against (GA)': '314',
#   '+ / -': '-20'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1993',
#   'Wins': '44',
#   'Losses': '27',
#   'OT Losses': '',
#   'Win %': '0.524',
#   'Goals For (GF)': '299',
#   'Goals Against (GA)': '285',
#   '+ / -': '14'},
#  {'Team Name': 'Quebec Nordiques',
#   'Year': '1993',
#   'Wins': '34',
#   'Losses': '42',
#   'OT Losses': '',
#   'Win %': '0.405',
#   'Goals For (GF)': '277',
#   'Goals Against (GA)': '292',
#   '+ / -': '-15'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '1993',
#   'Wins': '33',
#   'Losses': '35',
#   'OT Losses': '',
#   'Win %': '0.393',
#   'Goals For (GF)': '252',
#   'Goals Against (GA)': '265',
#   '+ / -': '-13'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1993',
#   'Wins': '40',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '270',
#   'Goals Against (GA)': '283',
#   '+ / -': '-13'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '1993',
#   'Wins': '30',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.357',
#   'Goals For (GF)': '224',
#   'Goals Against (GA)': '251',
#   '+ / -': '-27'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1993',
#   'Wins': '43',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.512',
#   'Goals For (GF)': '280',
#   'Goals Against (GA)': '243',
#   '+ / -': '37'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1993',
#   'Wins': '41',
#   'Losses': '40',
#   'OT Losses': '',
#   'Win %': '0.488',
#   'Goals For (GF)': '279',
#   'Goals Against (GA)': '276',
#   '+ / -': '3'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1993',
#   'Wins': '39',
#   'Losses': '35',
#   'OT Losses': '',
#   'Win %': '0.464',
#   'Goals For (GF)': '277',
#   'Goals Against (GA)': '263',
#   '+ / -': '14'},
#  {'Team Name': 'Winnipeg Jets',
#   'Year': '1993',
#   'Wins': '24',
#   'Losses': '51',
#   'OT Losses': '',
#   'Win %': '0.286',
#   'Goals For (GF)': '245',
#   'Goals Against (GA)': '344',
#   '+ / -': '-99'},
#  {'Team Name': 'Mighty Ducks of Anaheim',
#   'Year': '1994',
#   'Wins': '16',
#   'Losses': '27',
#   'OT Losses': '',
#   'Win %': '0.333',
#   'Goals For (GF)': '125',
#   'Goals Against (GA)': '164',
#   '+ / -': '-39'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1994',
#   'Wins': '27',
#   'Losses': '18',
#   'OT Losses': '',
#   'Win %': '0.562',
#   'Goals For (GF)': '150',
#   'Goals Against (GA)': '127',
#   '+ / -': '23'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1994',
#   'Wins': '22',
#   'Losses': '19',
#   'OT Losses': '',
#   'Win %': '0.458',
#   'Goals For (GF)': '130',
#   'Goals Against (GA)': '119',
#   '+ / -': '11'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1994',
#   'Wins': '24',
#   'Losses': '17',
#   'OT Losses': '',
#   'Win %': '0.5',
#   'Goals For (GF)': '163',
#   'Goals Against (GA)': '135',
#   '+ / -': '28'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1994',
#   'Wins': '24',
#   'Losses': '19',
#   'OT Losses': '',
#   'Win %': '0.5',
#   'Goals For (GF)': '156',
#   'Goals Against (GA)': '115',
#   '+ / -': '41'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '1994',
#   'Wins': '17',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.354',
#   'Goals For (GF)': '136',
#   'Goals Against (GA)': '135',
#   '+ / -': '1'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1994',
#   'Wins': '33',
#   'Losses': '11',
#   'OT Losses': '',
#   'Win %': '0.688',
#   'Goals For (GF)': '180',
#   'Goals Against (GA)': '117',
#   '+ / -': '63'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1994',
#   'Wins': '17',
#   'Losses': '27',
#   'OT Losses': '',
#   'Win %': '0.354',
#   'Goals For (GF)': '136',
#   'Goals Against (GA)': '183',
#   '+ / -': '-47'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '1994',
#   'Wins': '20',
#   'Losses': '22',
#   'OT Losses': '',
#   'Win %': '0.417',
#   'Goals For (GF)': '115',
#   'Goals Against (GA)': '127',
#   '+ / -': '-12'},
#  {'Team Name': 'Hartford Whalers',
#   'Year': '1994',
#   'Wins': '19',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.396',
#   'Goals For (GF)': '127',
#   'Goals Against (GA)': '141',
#   '+ / -': '-14'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1994',
#   'Wins': '16',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.333',
#   'Goals For (GF)': '142',
#   'Goals Against (GA)': '174',
#   '+ / -': '-32'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1994',
#   'Wins': '18',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.375',
#   'Goals For (GF)': '125',
#   'Goals Against (GA)': '148',
#   '+ / -': '-23'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1994',
#   'Wins': '22',
#   'Losses': '18',
#   'OT Losses': '',
#   'Win %': '0.458',
#   'Goals For (GF)': '136',
#   'Goals Against (GA)': '121',
#   '+ / -': '15'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1994',
#   'Wins': '15',
#   'Losses': '28',
#   'OT Losses': '',
#   'Win %': '0.312',
#   'Goals For (GF)': '126',
#   'Goals Against (GA)': '158',
#   '+ / -': '-32'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1994',
#   'Wins': '22',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.458',
#   'Goals For (GF)': '139',
#   'Goals Against (GA)': '134',
#   '+ / -': '5'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '1994',
#   'Wins': '9',
#   'Losses': '34',
#   'OT Losses': '',
#   'Win %': '0.188',
#   'Goals For (GF)': '117',
#   'Goals Against (GA)': '174',
#   '+ / -': '-57'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1994',
#   'Wins': '28',
#   'Losses': '16',
#   'OT Losses': '',
#   'Win %': '0.583',
#   'Goals For (GF)': '150',
#   'Goals Against (GA)': '132',
#   '+ / -': '18'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1994',
#   'Wins': '29',
#   'Losses': '16',
#   'OT Losses': '',
#   'Win %': '0.604',
#   'Goals For (GF)': '181',
#   'Goals Against (GA)': '158',
#   '+ / -': '23'},
#  {'Team Name': 'Quebec Nordiques',
#   'Year': '1994',
#   'Wins': '30',
#   'Losses': '13',
#   'OT Losses': '',
#   'Win %': '0.625',
#   'Goals For (GF)': '185',
#   'Goals Against (GA)': '134',
#   '+ / -': '51'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '1994',
#   'Wins': '19',
#   'Losses': '25',
#   'OT Losses': '',
#   'Win %': '0.396',
#   'Goals For (GF)': '129',
#   'Goals Against (GA)': '161',
#   '+ / -': '-32'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1994',
#   'Wins': '28',
#   'Losses': '15',
#   'OT Losses': '',
#   'Win %': '0.583',
#   'Goals For (GF)': '178',
#   'Goals Against (GA)': '135',
#   '+ / -': '43'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '1994',
#   'Wins': '17',
#   'Losses': '28',
#   'OT Losses': '',
#   'Win %': '0.354',
#   'Goals For (GF)': '120',
#   'Goals Against (GA)': '144',
#   '+ / -': '-24'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1994',
#   'Wins': '21',
#   'Losses': '19',
#   'OT Losses': '',
#   'Win %': '0.438',
#   'Goals For (GF)': '135',
#   'Goals Against (GA)': '146',
#   '+ / -': '-11'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1994',
#   'Wins': '18',
#   'Losses': '18',
#   'OT Losses': '',
#   'Win %': '0.375',
#   'Goals For (GF)': '153',
#   'Goals Against (GA)': '148',
#   '+ / -': '5'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1994',
#   'Wins': '22',
#   'Losses': '18',
#   'OT Losses': '',
#   'Win %': '0.458',
#   'Goals For (GF)': '136',
#   'Goals Against (GA)': '120',
#   '+ / -': '16'},
#  {'Team Name': 'Winnipeg Jets',
#   'Year': '1994',
#   'Wins': '16',
#   'Losses': '25',
#   'OT Losses': '',
#   'Win %': '0.333',
#   'Goals For (GF)': '157',
#   'Goals Against (GA)': '177',
#   '+ / -': '-20'},
#  {'Team Name': 'Mighty Ducks of Anaheim',
#   'Year': '1995',
#   'Wins': '35',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.427',
#   'Goals For (GF)': '234',
#   'Goals Against (GA)': '247',
#   '+ / -': '-13'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1995',
#   'Wins': '40',
#   'Losses': '31',
#   'OT Losses': '',
#   'Win %': '0.488',
#   'Goals For (GF)': '282',
#   'Goals Against (GA)': '269',
#   '+ / -': '13'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1995',
#   'Wins': '33',
#   'Losses': '42',
#   'OT Losses': '',
#   'Win %': '0.402',
#   'Goals For (GF)': '247',
#   'Goals Against (GA)': '262',
#   '+ / -': '-15'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1995',
#   'Wins': '34',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.415',
#   'Goals For (GF)': '241',
#   'Goals Against (GA)': '240',
#   '+ / -': '1'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1995',
#   'Wins': '40',
#   'Losses': '28',
#   'OT Losses': '',
#   'Win %': '0.488',
#   'Goals For (GF)': '273',
#   'Goals Against (GA)': '220',
#   '+ / -': '53'},
#  {'Team Name': 'Colorado Avalanche',
#   'Year': '1995',
#   'Wins': '47',
#   'Losses': '25',
#   'OT Losses': '',
#   'Win %': '0.573',
#   'Goals For (GF)': '326',
#   'Goals Against (GA)': '240',
#   '+ / -': '86'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '1995',
#   'Wins': '26',
#   'Losses': '42',
#   'OT Losses': '',
#   'Win %': '0.317',
#   'Goals For (GF)': '227',
#   'Goals Against (GA)': '280',
#   '+ / -': '-53'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1995',
#   'Wins': '62',
#   'Losses': '13',
#   'OT Losses': '',
#   'Win %': '0.756',
#   'Goals For (GF)': '325',
#   'Goals Against (GA)': '181',
#   '+ / -': '144'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1995',
#   'Wins': '30',
#   'Losses': '44',
#   'OT Losses': '',
#   'Win %': '0.366',
#   'Goals For (GF)': '240',
#   'Goals Against (GA)': '304',
#   '+ / -': '-64'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '1995',
#   'Wins': '41',
#   'Losses': '31',
#   'OT Losses': '',
#   'Win %': '0.5',
#   'Goals For (GF)': '254',
#   'Goals Against (GA)': '234',
#   '+ / -': '20'},
#  {'Team Name': 'Hartford Whalers',
#   'Year': '1995',
#   'Wins': '34',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.415',
#   'Goals For (GF)': '237',
#   'Goals Against (GA)': '259',
#   '+ / -': '-22'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1995',
#   'Wins': '24',
#   'Losses': '40',
#   'OT Losses': '',
#   'Win %': '0.293',
#   'Goals For (GF)': '256',
#   'Goals Against (GA)': '302',
#   '+ / -': '-46'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1995',
#   'Wins': '40',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.488',
#   'Goals For (GF)': '265',
#   'Goals Against (GA)': '248',
#   '+ / -': '17'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1995',
#   'Wins': '37',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.451',
#   'Goals For (GF)': '215',
#   'Goals Against (GA)': '202',
#   '+ / -': '13'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1995',
#   'Wins': '22',
#   'Losses': '50',
#   'OT Losses': '',
#   'Win %': '0.268',
#   'Goals For (GF)': '229',
#   'Goals Against (GA)': '315',
#   '+ / -': '-86'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1995',
#   'Wins': '41',
#   'Losses': '27',
#   'OT Losses': '',
#   'Win %': '0.5',
#   'Goals For (GF)': '272',
#   'Goals Against (GA)': '237',
#   '+ / -': '35'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '1995',
#   'Wins': '18',
#   'Losses': '59',
#   'OT Losses': '',
#   'Win %': '0.22',
#   'Goals For (GF)': '191',
#   'Goals Against (GA)': '291',
#   '+ / -': '-100'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1995',
#   'Wins': '45',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.549',
#   'Goals For (GF)': '282',
#   'Goals Against (GA)': '208',
#   '+ / -': '74'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1995',
#   'Wins': '49',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.598',
#   'Goals For (GF)': '362',
#   'Goals Against (GA)': '284',
#   '+ / -': '78'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '1995',
#   'Wins': '20',
#   'Losses': '55',
#   'OT Losses': '',
#   'Win %': '0.244',
#   'Goals For (GF)': '252',
#   'Goals Against (GA)': '357',
#   '+ / -': '-105'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1995',
#   'Wins': '32',
#   'Losses': '34',
#   'OT Losses': '',
#   'Win %': '0.39',
#   'Goals For (GF)': '219',
#   'Goals Against (GA)': '248',
#   '+ / -': '-29'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '1995',
#   'Wins': '38',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '238',
#   'Goals Against (GA)': '248',
#   '+ / -': '-10'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1995',
#   'Wins': '34',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.415',
#   'Goals For (GF)': '247',
#   'Goals Against (GA)': '252',
#   '+ / -': '-5'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1995',
#   'Wins': '32',
#   'Losses': '35',
#   'OT Losses': '',
#   'Win %': '0.39',
#   'Goals For (GF)': '278',
#   'Goals Against (GA)': '278',
#   '+ / -': '0'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1995',
#   'Wins': '39',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '234',
#   'Goals Against (GA)': '204',
#   '+ / -': '30'},
#  {'Team Name': 'Winnipeg Jets',
#   'Year': '1995',
#   'Wins': '36',
#   'Losses': '40',
#   'OT Losses': '',
#   'Win %': '0.439',
#   'Goals For (GF)': '275',
#   'Goals Against (GA)': '291',
#   '+ / -': '-16'},
#  {'Team Name': 'Mighty Ducks of Anaheim',
#   'Year': '1996',
#   'Wins': '36',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.439',
#   'Goals For (GF)': '245',
#   'Goals Against (GA)': '233',
#   '+ / -': '12'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1996',
#   'Wins': '26',
#   'Losses': '47',
#   'OT Losses': '',
#   'Win %': '0.317',
#   'Goals For (GF)': '234',
#   'Goals Against (GA)': '300',
#   '+ / -': '-66'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1996',
#   'Wins': '40',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.488',
#   'Goals For (GF)': '237',
#   'Goals Against (GA)': '208',
#   '+ / -': '29'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1996',
#   'Wins': '32',
#   'Losses': '41',
#   'OT Losses': '',
#   'Win %': '0.39',
#   'Goals For (GF)': '214',
#   'Goals Against (GA)': '239',
#   '+ / -': '-25'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1996',
#   'Wins': '34',
#   'Losses': '35',
#   'OT Losses': '',
#   'Win %': '0.415',
#   'Goals For (GF)': '223',
#   'Goals Against (GA)': '210',
#   '+ / -': '13'},
#  {'Team Name': 'Colorado Avalanche',
#   'Year': '1996',
#   'Wins': '49',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.598',
#   'Goals For (GF)': '277',
#   'Goals Against (GA)': '205',
#   '+ / -': '72'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '1996',
#   'Wins': '48',
#   'Losses': '26',
#   'OT Losses': '',
#   'Win %': '0.585',
#   'Goals For (GF)': '252',
#   'Goals Against (GA)': '198',
#   '+ / -': '54'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1996',
#   'Wins': '38',
#   'Losses': '26',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '253',
#   'Goals Against (GA)': '197',
#   '+ / -': '56'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1996',
#   'Wins': '36',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.439',
#   'Goals For (GF)': '252',
#   'Goals Against (GA)': '247',
#   '+ / -': '5'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '1996',
#   'Wins': '35',
#   'Losses': '28',
#   'OT Losses': '',
#   'Win %': '0.427',
#   'Goals For (GF)': '221',
#   'Goals Against (GA)': '201',
#   '+ / -': '20'},
#  {'Team Name': 'Hartford Whalers',
#   'Year': '1996',
#   'Wins': '32',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.39',
#   'Goals For (GF)': '226',
#   'Goals Against (GA)': '256',
#   '+ / -': '-30'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1996',
#   'Wins': '28',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.341',
#   'Goals For (GF)': '214',
#   'Goals Against (GA)': '268',
#   '+ / -': '-54'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1996',
#   'Wins': '31',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.378',
#   'Goals For (GF)': '249',
#   'Goals Against (GA)': '276',
#   '+ / -': '-27'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1996',
#   'Wins': '45',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.549',
#   'Goals For (GF)': '231',
#   'Goals Against (GA)': '182',
#   '+ / -': '49'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1996',
#   'Wins': '29',
#   'Losses': '41',
#   'OT Losses': '',
#   'Win %': '0.354',
#   'Goals For (GF)': '240',
#   'Goals Against (GA)': '250',
#   '+ / -': '-10'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1996',
#   'Wins': '38',
#   'Losses': '34',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '258',
#   'Goals Against (GA)': '231',
#   '+ / -': '27'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '1996',
#   'Wins': '31',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.378',
#   'Goals For (GF)': '226',
#   'Goals Against (GA)': '234',
#   '+ / -': '-8'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1996',
#   'Wins': '45',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.549',
#   'Goals For (GF)': '274',
#   'Goals Against (GA)': '217',
#   '+ / -': '57'},
#  {'Team Name': 'Phoenix Coyotes',
#   'Year': '1996',
#   'Wins': '38',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '240',
#   'Goals Against (GA)': '243',
#   '+ / -': '-3'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1996',
#   'Wins': '38',
#   'Losses': '36',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '285',
#   'Goals Against (GA)': '280',
#   '+ / -': '5'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '1996',
#   'Wins': '27',
#   'Losses': '47',
#   'OT Losses': '',
#   'Win %': '0.329',
#   'Goals For (GF)': '211',
#   'Goals Against (GA)': '278',
#   '+ / -': '-67'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1996',
#   'Wins': '36',
#   'Losses': '35',
#   'OT Losses': '',
#   'Win %': '0.439',
#   'Goals For (GF)': '236',
#   'Goals Against (GA)': '239',
#   '+ / -': '-3'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '1996',
#   'Wins': '32',
#   'Losses': '40',
#   'OT Losses': '',
#   'Win %': '0.39',
#   'Goals For (GF)': '217',
#   'Goals Against (GA)': '247',
#   '+ / -': '-30'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1996',
#   'Wins': '30',
#   'Losses': '44',
#   'OT Losses': '',
#   'Win %': '0.366',
#   'Goals For (GF)': '230',
#   'Goals Against (GA)': '273',
#   '+ / -': '-43'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1996',
#   'Wins': '35',
#   'Losses': '40',
#   'OT Losses': '',
#   'Win %': '0.427',
#   'Goals For (GF)': '257',
#   'Goals Against (GA)': '273',
#   '+ / -': '-16'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1996',
#   'Wins': '33',
#   'Losses': '40',
#   'OT Losses': '',
#   'Win %': '0.402',
#   'Goals For (GF)': '214',
#   'Goals Against (GA)': '231',
#   '+ / -': '-17'},
#  {'Team Name': 'Mighty Ducks of Anaheim',
#   'Year': '1997',
#   'Wins': '26',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.317',
#   'Goals For (GF)': '205',
#   'Goals Against (GA)': '261',
#   '+ / -': '-56'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1997',
#   'Wins': '39',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '221',
#   'Goals Against (GA)': '194',
#   '+ / -': '27'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1997',
#   'Wins': '36',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.439',
#   'Goals For (GF)': '211',
#   'Goals Against (GA)': '187',
#   '+ / -': '24'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1997',
#   'Wins': '26',
#   'Losses': '41',
#   'OT Losses': '',
#   'Win %': '0.317',
#   'Goals For (GF)': '217',
#   'Goals Against (GA)': '252',
#   '+ / -': '-35'},
#  {'Team Name': 'Carolina Hurricanes',
#   'Year': '1997',
#   'Wins': '33',
#   'Losses': '41',
#   'OT Losses': '',
#   'Win %': '0.402',
#   'Goals For (GF)': '200',
#   'Goals Against (GA)': '219',
#   '+ / -': '-19'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1997',
#   'Wins': '30',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.366',
#   'Goals For (GF)': '192',
#   'Goals Against (GA)': '199',
#   '+ / -': '-7'},
#  {'Team Name': 'Colorado Avalanche',
#   'Year': '1997',
#   'Wins': '39',
#   'Losses': '26',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '231',
#   'Goals Against (GA)': '205',
#   '+ / -': '26'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '1997',
#   'Wins': '49',
#   'Losses': '22',
#   'OT Losses': '',
#   'Win %': '0.598',
#   'Goals For (GF)': '242',
#   'Goals Against (GA)': '167',
#   '+ / -': '75'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1997',
#   'Wins': '44',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.537',
#   'Goals For (GF)': '250',
#   'Goals Against (GA)': '196',
#   '+ / -': '54'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1997',
#   'Wins': '35',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.427',
#   'Goals For (GF)': '215',
#   'Goals Against (GA)': '224',
#   '+ / -': '-9'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '1997',
#   'Wins': '24',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.293',
#   'Goals For (GF)': '203',
#   'Goals Against (GA)': '256',
#   '+ / -': '-53'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1997',
#   'Wins': '38',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '227',
#   'Goals Against (GA)': '225',
#   '+ / -': '2'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1997',
#   'Wins': '37',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.451',
#   'Goals For (GF)': '235',
#   'Goals Against (GA)': '208',
#   '+ / -': '27'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1997',
#   'Wins': '48',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.585',
#   'Goals For (GF)': '225',
#   'Goals Against (GA)': '166',
#   '+ / -': '59'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1997',
#   'Wins': '30',
#   'Losses': '41',
#   'OT Losses': '',
#   'Win %': '0.366',
#   'Goals For (GF)': '212',
#   'Goals Against (GA)': '225',
#   '+ / -': '-13'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1997',
#   'Wins': '25',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.305',
#   'Goals For (GF)': '197',
#   'Goals Against (GA)': '231',
#   '+ / -': '-34'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '1997',
#   'Wins': '34',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.415',
#   'Goals For (GF)': '193',
#   'Goals Against (GA)': '200',
#   '+ / -': '-7'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1997',
#   'Wins': '42',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.512',
#   'Goals For (GF)': '242',
#   'Goals Against (GA)': '193',
#   '+ / -': '49'},
#  {'Team Name': 'Phoenix Coyotes',
#   'Year': '1997',
#   'Wins': '35',
#   'Losses': '35',
#   'OT Losses': '',
#   'Win %': '0.427',
#   'Goals For (GF)': '224',
#   'Goals Against (GA)': '227',
#   '+ / -': '-3'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1997',
#   'Wins': '40',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.488',
#   'Goals For (GF)': '228',
#   'Goals Against (GA)': '188',
#   '+ / -': '40'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '1997',
#   'Wins': '34',
#   'Losses': '38',
#   'OT Losses': '',
#   'Win %': '0.415',
#   'Goals For (GF)': '210',
#   'Goals Against (GA)': '216',
#   '+ / -': '-6'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1997',
#   'Wins': '45',
#   'Losses': '29',
#   'OT Losses': '',
#   'Win %': '0.549',
#   'Goals For (GF)': '256',
#   'Goals Against (GA)': '204',
#   '+ / -': '52'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '1997',
#   'Wins': '17',
#   'Losses': '55',
#   'OT Losses': '',
#   'Win %': '0.207',
#   'Goals For (GF)': '151',
#   'Goals Against (GA)': '269',
#   '+ / -': '-118'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1997',
#   'Wins': '30',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.366',
#   'Goals For (GF)': '194',
#   'Goals Against (GA)': '237',
#   '+ / -': '-43'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1997',
#   'Wins': '25',
#   'Losses': '43',
#   'OT Losses': '',
#   'Win %': '0.305',
#   'Goals For (GF)': '224',
#   'Goals Against (GA)': '273',
#   '+ / -': '-49'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1997',
#   'Wins': '40',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.488',
#   'Goals For (GF)': '219',
#   'Goals Against (GA)': '202',
#   '+ / -': '17'},
#  {'Team Name': 'Mighty Ducks of Anaheim',
#   'Year': '1998',
#   'Wins': '35',
#   'Losses': '34',
#   'OT Losses': '',
#   'Win %': '0.427',
#   'Goals For (GF)': '215',
#   'Goals Against (GA)': '206',
#   '+ / -': '9'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1998',
#   'Wins': '39',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '214',
#   'Goals Against (GA)': '181',
#   '+ / -': '33'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1998',
#   'Wins': '37',
#   'Losses': '28',
#   'OT Losses': '',
#   'Win %': '0.451',
#   'Goals For (GF)': '207',
#   'Goals Against (GA)': '175',
#   '+ / -': '32'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1998',
#   'Wins': '30',
#   'Losses': '40',
#   'OT Losses': '',
#   'Win %': '0.366',
#   'Goals For (GF)': '211',
#   'Goals Against (GA)': '234',
#   '+ / -': '-23'},
#  {'Team Name': 'Carolina Hurricanes',
#   'Year': '1998',
#   'Wins': '34',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.415',
#   'Goals For (GF)': '210',
#   'Goals Against (GA)': '202',
#   '+ / -': '8'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1998',
#   'Wins': '29',
#   'Losses': '41',
#   'OT Losses': '',
#   'Win %': '0.354',
#   'Goals For (GF)': '202',
#   'Goals Against (GA)': '248',
#   '+ / -': '-46'},
#  {'Team Name': 'Colorado Avalanche',
#   'Year': '1998',
#   'Wins': '44',
#   'Losses': '28',
#   'OT Losses': '',
#   'Win %': '0.537',
#   'Goals For (GF)': '239',
#   'Goals Against (GA)': '205',
#   '+ / -': '34'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '1998',
#   'Wins': '51',
#   'Losses': '19',
#   'OT Losses': '',
#   'Win %': '0.622',
#   'Goals For (GF)': '236',
#   'Goals Against (GA)': '168',
#   '+ / -': '68'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1998',
#   'Wins': '43',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.524',
#   'Goals For (GF)': '245',
#   'Goals Against (GA)': '202',
#   '+ / -': '43'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1998',
#   'Wins': '33',
#   'Losses': '37',
#   'OT Losses': '',
#   'Win %': '0.402',
#   'Goals For (GF)': '230',
#   'Goals Against (GA)': '226',
#   '+ / -': '4'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '1998',
#   'Wins': '30',
#   'Losses': '34',
#   'OT Losses': '',
#   'Win %': '0.366',
#   'Goals For (GF)': '210',
#   'Goals Against (GA)': '228',
#   '+ / -': '-18'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1998',
#   'Wins': '32',
#   'Losses': '45',
#   'OT Losses': '',
#   'Win %': '0.39',
#   'Goals For (GF)': '189',
#   'Goals Against (GA)': '222',
#   '+ / -': '-33'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '1998',
#   'Wins': '32',
#   'Losses': '39',
#   'OT Losses': '',
#   'Win %': '0.39',
#   'Goals For (GF)': '184',
#   'Goals Against (GA)': '209',
#   '+ / -': '-25'},
#  {'Team Name': 'Nashville Predators',
#   'Year': '1998',
#   'Wins': '28',
#   'Losses': '47',
#   'OT Losses': '',
#   'Win %': '0.341',
#   'Goals For (GF)': '190',
#   'Goals Against (GA)': '261',
#   '+ / -': '-71'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '1998',
#   'Wins': '47',
#   'Losses': '24',
#   'OT Losses': '',
#   'Win %': '0.573',
#   'Goals For (GF)': '248',
#   'Goals Against (GA)': '196',
#   '+ / -': '52'},
#  {'Team Name': 'New York Islanders',
#   'Year': '1998',
#   'Wins': '24',
#   'Losses': '48',
#   'OT Losses': '',
#   'Win %': '0.293',
#   'Goals For (GF)': '194',
#   'Goals Against (GA)': '244',
#   '+ / -': '-50'},
#  {'Team Name': 'New York Rangers',
#   'Year': '1998',
#   'Wins': '33',
#   'Losses': '38',
#   'OT Losses': '',
#   'Win %': '0.402',
#   'Goals For (GF)': '217',
#   'Goals Against (GA)': '227',
#   '+ / -': '-10'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '1998',
#   'Wins': '44',
#   'Losses': '23',
#   'OT Losses': '',
#   'Win %': '0.537',
#   'Goals For (GF)': '239',
#   'Goals Against (GA)': '179',
#   '+ / -': '60'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '1998',
#   'Wins': '37',
#   'Losses': '26',
#   'OT Losses': '',
#   'Win %': '0.451',
#   'Goals For (GF)': '231',
#   'Goals Against (GA)': '196',
#   '+ / -': '35'},
#  {'Team Name': 'Phoenix Coyotes',
#   'Year': '1998',
#   'Wins': '39',
#   'Losses': '31',
#   'OT Losses': '',
#   'Win %': '0.476',
#   'Goals For (GF)': '205',
#   'Goals Against (GA)': '197',
#   '+ / -': '8'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '1998',
#   'Wins': '38',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.463',
#   'Goals For (GF)': '242',
#   'Goals Against (GA)': '225',
#   '+ / -': '17'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '1998',
#   'Wins': '31',
#   'Losses': '33',
#   'OT Losses': '',
#   'Win %': '0.378',
#   'Goals For (GF)': '196',
#   'Goals Against (GA)': '191',
#   '+ / -': '5'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '1998',
#   'Wins': '37',
#   'Losses': '32',
#   'OT Losses': '',
#   'Win %': '0.451',
#   'Goals For (GF)': '237',
#   'Goals Against (GA)': '209',
#   '+ / -': '28'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '1998',
#   'Wins': '19',
#   'Losses': '54',
#   'OT Losses': '',
#   'Win %': '0.232',
#   'Goals For (GF)': '179',
#   'Goals Against (GA)': '292',
#   '+ / -': '-113'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '1998',
#   'Wins': '45',
#   'Losses': '30',
#   'OT Losses': '',
#   'Win %': '0.549',
#   'Goals For (GF)': '268',
#   'Goals Against (GA)': '231',
#   '+ / -': '37'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '1998',
#   'Wins': '23',
#   'Losses': '47',
#   'OT Losses': '',
#   'Win %': '0.28',
#   'Goals For (GF)': '192',
#   'Goals Against (GA)': '258',
#   '+ / -': '-66'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '1998',
#   'Wins': '31',
#   'Losses': '45',
#   'OT Losses': '',
#   'Win %': '0.378',
#   'Goals For (GF)': '200',
#   'Goals Against (GA)': '218',
#   '+ / -': '-18'},
#  {'Team Name': 'Mighty Ducks of Anaheim',
#   'Year': '1999',
#   'Wins': '34',
#   'Losses': '33',
#   'OT Losses': '3',
#   'Win %': '0.415',
#   'Goals For (GF)': '217',
#   'Goals Against (GA)': '227',
#   '+ / -': '-10'},
#  {'Team Name': 'Atlanta Thrashers',
#   'Year': '1999',
#   'Wins': '14',
#   'Losses': '57',
#   'OT Losses': '4',
#   'Win %': '0.171',
#   'Goals For (GF)': '170',
#   'Goals Against (GA)': '313',
#   '+ / -': '-143'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '1999',
#   'Wins': '24',
#   'Losses': '33',
#   'OT Losses': '6',
#   'Win %': '0.293',
#   'Goals For (GF)': '210',
#   'Goals Against (GA)': '248',
#   '+ / -': '-38'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '1999',
#   'Wins': '35',
#   'Losses': '32',
#   'OT Losses': '4',
#   'Win %': '0.427',
#   'Goals For (GF)': '213',
#   'Goals Against (GA)': '204',
#   '+ / -': '9'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '1999',
#   'Wins': '31',
#   'Losses': '36',
#   'OT Losses': '5',
#   'Win %': '0.378',
#   'Goals For (GF)': '211',
#   'Goals Against (GA)': '256',
#   '+ / -': '-45'},
#  {'Team Name': 'Carolina Hurricanes',
#   'Year': '1999',
#   'Wins': '37',
#   'Losses': '35',
#   'OT Losses': '0',
#   'Win %': '0.451',
#   'Goals For (GF)': '217',
#   'Goals Against (GA)': '216',
#   '+ / -': '1'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '1999',
#   'Wins': '33',
#   'Losses': '37',
#   'OT Losses': '2',
#   'Win %': '0.402',
#   'Goals For (GF)': '242',
#   'Goals Against (GA)': '245',
#   '+ / -': '-3'},
#  {'Team Name': 'Colorado Avalanche',
#   'Year': '1999',
#   'Wins': '42',
#   'Losses': '28',
#   'OT Losses': '1',
#   'Win %': '0.512',
#   'Goals For (GF)': '233',
#   'Goals Against (GA)': '201',
#   '+ / -': '32'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '1999',
#   'Wins': '43',
#   'Losses': '23',
#   'OT Losses': '6',
#   'Win %': '0.524',
#   'Goals For (GF)': '211',
#   'Goals Against (GA)': '184',
#   '+ / -': '27'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '1999',
#   'Wins': '48',
#   'Losses': '22',
#   'OT Losses': '2',
#   'Win %': '0.585',
#   'Goals For (GF)': '278',
#   'Goals Against (GA)': '210',
#   '+ / -': '68'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '1999',
#   'Wins': '32',
#   'Losses': '26',
#   'OT Losses': '8',
#   'Win %': '0.39',
#   'Goals For (GF)': '226',
#   'Goals Against (GA)': '212',
#   '+ / -': '14'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '1999',
#   'Wins': '43',
#   'Losses': '27',
#   'OT Losses': '6',
#   'Win %': '0.524',
#   'Goals For (GF)': '244',
#   'Goals Against (GA)': '209',
#   '+ / -': '35'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '1999',
#   'Wins': '39',
#   'Losses': '27',
#   'OT Losses': '4',
#   'Win %': '0.476',
# ...
#   'Goals Against (GA)': '284',
#   '+ / -': '-70'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '2009',
#   'Wins': '32',
#   'Losses': '37',
#   'OT Losses': '13',
#   'Win %': '0.39',
#   'Goals For (GF)': '208',
#   'Goals Against (GA)': '244',
#   '+ / -': '-36'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '2009',
#   'Wins': '46',
#   'Losses': '27',
#   'OT Losses': '9',
#   'Win %': '0.561',
#   'Goals For (GF)': '241',
#   'Goals Against (GA)': '219',
#   '+ / -': '22'},
#  {'Team Name': 'Minnesota Wild',
#   'Year': '2009',
#   'Wins': '38',
#   'Losses': '36',
#   'OT Losses': '8',
#   'Win %': '0.463',
#   'Goals For (GF)': '219',
#   'Goals Against (GA)': '246',
#   '+ / -': '-27'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '2009',
#   'Wins': '39',
#   'Losses': '33',
#   'OT Losses': '10',
#   'Win %': '0.476',
#   'Goals For (GF)': '217',
#   'Goals Against (GA)': '223',
#   '+ / -': '-6'},
#  {'Team Name': 'Nashville Predators',
#   'Year': '2009',
#   'Wins': '47',
#   'Losses': '29',
#   'OT Losses': '6',
#   'Win %': '0.573',
#   'Goals For (GF)': '225',
#   'Goals Against (GA)': '225',
#   '+ / -': '0'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '2009',
#   'Wins': '48',
#   'Losses': '27',
#   'OT Losses': '7',
#   'Win %': '0.585',
#   'Goals For (GF)': '222',
#   'Goals Against (GA)': '191',
#   '+ / -': '31'},
#  {'Team Name': 'New York Islanders',
#   'Year': '2009',
#   'Wins': '34',
#   'Losses': '37',
#   'OT Losses': '11',
#   'Win %': '0.415',
#   'Goals For (GF)': '222',
#   'Goals Against (GA)': '264',
#   '+ / -': '-42'},
#  {'Team Name': 'New York Rangers',
#   'Year': '2009',
#   'Wins': '38',
#   'Losses': '33',
#   'OT Losses': '11',
#   'Win %': '0.463',
#   'Goals For (GF)': '222',
#   'Goals Against (GA)': '218',
#   '+ / -': '4'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '2009',
#   'Wins': '44',
#   'Losses': '32',
#   'OT Losses': '6',
#   'Win %': '0.537',
#   'Goals For (GF)': '225',
#   'Goals Against (GA)': '238',
#   '+ / -': '-13'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '2009',
#   'Wins': '41',
#   'Losses': '35',
#   'OT Losses': '6',
#   'Win %': '0.5',
#   'Goals For (GF)': '236',
#   'Goals Against (GA)': '225',
#   '+ / -': '11'},
#  {'Team Name': 'Phoenix Coyotes',
#   'Year': '2009',
#   'Wins': '50',
#   'Losses': '25',
#   'OT Losses': '7',
#   'Win %': '0.61',
#   'Goals For (GF)': '225',
#   'Goals Against (GA)': '202',
#   '+ / -': '23'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '2009',
#   'Wins': '47',
#   'Losses': '28',
#   'OT Losses': '7',
#   'Win %': '0.573',
#   'Goals For (GF)': '257',
#   'Goals Against (GA)': '237',
#   '+ / -': '20'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '2009',
#   'Wins': '51',
#   'Losses': '20',
#   'OT Losses': '11',
#   'Win %': '0.622',
#   'Goals For (GF)': '264',
#   'Goals Against (GA)': '215',
#   '+ / -': '49'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '2009',
#   'Wins': '40',
#   'Losses': '32',
#   'OT Losses': '10',
#   'Win %': '0.488',
#   'Goals For (GF)': '225',
#   'Goals Against (GA)': '223',
#   '+ / -': '2'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '2009',
#   'Wins': '34',
#   'Losses': '36',
#   'OT Losses': '12',
#   'Win %': '0.415',
#   'Goals For (GF)': '217',
#   'Goals Against (GA)': '260',
#   '+ / -': '-43'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '2009',
#   'Wins': '30',
#   'Losses': '38',
#   'OT Losses': '14',
#   'Win %': '0.366',
#   'Goals For (GF)': '214',
#   'Goals Against (GA)': '267',
#   '+ / -': '-53'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '2009',
#   'Wins': '49',
#   'Losses': '28',
#   'OT Losses': '5',
#   'Win %': '0.598',
#   'Goals For (GF)': '272',
#   'Goals Against (GA)': '222',
#   '+ / -': '50'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '2009',
#   'Wins': '54',
#   'Losses': '15',
#   'OT Losses': '13',
#   'Win %': '0.659',
#   'Goals For (GF)': '318',
#   'Goals Against (GA)': '233',
#   '+ / -': '85'},
#  {'Team Name': 'Anaheim Ducks',
#   'Year': '2010',
#   'Wins': '47',
#   'Losses': '30',
#   'OT Losses': '5',
#   'Win %': '0.573',
#   'Goals For (GF)': '239',
#   'Goals Against (GA)': '235',
#   '+ / -': '4'},
#  {'Team Name': 'Atlanta Thrashers',
#   'Year': '2010',
#   'Wins': '34',
#   'Losses': '36',
#   'OT Losses': '12',
#   'Win %': '0.415',
#   'Goals For (GF)': '223',
#   'Goals Against (GA)': '269',
#   '+ / -': '-46'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '2010',
#   'Wins': '46',
#   'Losses': '25',
#   'OT Losses': '11',
#   'Win %': '0.561',
#   'Goals For (GF)': '246',
#   'Goals Against (GA)': '195',
#   '+ / -': '51'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '2010',
#   'Wins': '43',
#   'Losses': '29',
#   'OT Losses': '10',
#   'Win %': '0.524',
#   'Goals For (GF)': '245',
#   'Goals Against (GA)': '229',
#   '+ / -': '16'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '2010',
#   'Wins': '41',
#   'Losses': '29',
#   'OT Losses': '12',
#   'Win %': '0.5',
#   'Goals For (GF)': '250',
#   'Goals Against (GA)': '237',
#   '+ / -': '13'},
#  {'Team Name': 'Carolina Hurricanes',
#   'Year': '2010',
#   'Wins': '40',
#   'Losses': '31',
#   'OT Losses': '11',
#   'Win %': '0.488',
#   'Goals For (GF)': '236',
#   'Goals Against (GA)': '239',
#   '+ / -': '-3'},
#  {'Team Name': 'Columbus Blue Jackets',
#   'Year': '2010',
#   'Wins': '34',
#   'Losses': '35',
#   'OT Losses': '13',
#   'Win %': '0.415',
#   'Goals For (GF)': '215',
#   'Goals Against (GA)': '258',
#   '+ / -': '-43'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '2010',
#   'Wins': '44',
#   'Losses': '29',
#   'OT Losses': '9',
#   'Win %': '0.537',
#   'Goals For (GF)': '258',
#   'Goals Against (GA)': '225',
#   '+ / -': '33'},
#  {'Team Name': 'Colorado Avalanche',
#   'Year': '2010',
#   'Wins': '30',
#   'Losses': '44',
#   'OT Losses': '8',
#   'Win %': '0.366',
#   'Goals For (GF)': '227',
#   'Goals Against (GA)': '288',
#   '+ / -': '-61'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '2010',
#   'Wins': '42',
#   'Losses': '29',
#   'OT Losses': '11',
#   'Win %': '0.512',
#   'Goals For (GF)': '227',
#   'Goals Against (GA)': '233',
#   '+ / -': '-6'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '2010',
#   'Wins': '47',
#   'Losses': '25',
#   'OT Losses': '10',
#   'Win %': '0.573',
#   'Goals For (GF)': '261',
#   'Goals Against (GA)': '241',
#   '+ / -': '20'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '2010',
#   'Wins': '25',
#   'Losses': '45',
#   'OT Losses': '12',
#   'Win %': '0.305',
#   'Goals For (GF)': '193',
#   'Goals Against (GA)': '269',
#   '+ / -': '-76'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '2010',
#   'Wins': '30',
#   'Losses': '40',
#   'OT Losses': '12',
#   'Win %': '0.366',
#   'Goals For (GF)': '195',
#   'Goals Against (GA)': '229',
#   '+ / -': '-34'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '2010',
#   'Wins': '46',
#   'Losses': '30',
#   'OT Losses': '6',
#   'Win %': '0.561',
#   'Goals For (GF)': '219',
#   'Goals Against (GA)': '198',
#   '+ / -': '21'},
#  {'Team Name': 'Minnesota Wild',
#   'Year': '2010',
#   'Wins': '39',
#   'Losses': '35',
#   'OT Losses': '8',
#   'Win %': '0.476',
#   'Goals For (GF)': '206',
#   'Goals Against (GA)': '233',
#   '+ / -': '-27'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '2010',
#   'Wins': '44',
#   'Losses': '30',
#   'OT Losses': '8',
#   'Win %': '0.537',
#   'Goals For (GF)': '216',
#   'Goals Against (GA)': '209',
#   '+ / -': '7'},
#  {'Team Name': 'Nashville Predators',
#   'Year': '2010',
#   'Wins': '44',
#   'Losses': '27',
#   'OT Losses': '11',
#   'Win %': '0.537',
#   'Goals For (GF)': '219',
#   'Goals Against (GA)': '194',
#   '+ / -': '25'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '2010',
#   'Wins': '38',
#   'Losses': '39',
#   'OT Losses': '5',
#   'Win %': '0.463',
#   'Goals For (GF)': '174',
#   'Goals Against (GA)': '209',
#   '+ / -': '-35'},
#  {'Team Name': 'New York Islanders',
#   'Year': '2010',
#   'Wins': '30',
#   'Losses': '39',
#   'OT Losses': '13',
#   'Win %': '0.366',
#   'Goals For (GF)': '229',
#   'Goals Against (GA)': '264',
#   '+ / -': '-35'},
#  {'Team Name': 'New York Rangers',
#   'Year': '2010',
#   'Wins': '44',
#   'Losses': '33',
#   'OT Losses': '5',
#   'Win %': '0.537',
#   'Goals For (GF)': '233',
#   'Goals Against (GA)': '198',
#   '+ / -': '35'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '2010',
#   'Wins': '32',
#   'Losses': '40',
#   'OT Losses': '10',
#   'Win %': '0.39',
#   'Goals For (GF)': '192',
#   'Goals Against (GA)': '250',
#   '+ / -': '-58'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '2010',
#   'Wins': '47',
#   'Losses': '23',
#   'OT Losses': '12',
#   'Win %': '0.573',
#   'Goals For (GF)': '259',
#   'Goals Against (GA)': '223',
#   '+ / -': '36'},
#  {'Team Name': 'Phoenix Coyotes',
#   'Year': '2010',
#   'Wins': '43',
#   'Losses': '26',
#   'OT Losses': '13',
#   'Win %': '0.524',
#   'Goals For (GF)': '231',
#   'Goals Against (GA)': '226',
#   '+ / -': '5'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '2010',
#   'Wins': '49',
#   'Losses': '25',
#   'OT Losses': '8',
#   'Win %': '0.598',
#   'Goals For (GF)': '238',
#   'Goals Against (GA)': '199',
#   '+ / -': '39'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '2010',
#   'Wins': '48',
#   'Losses': '25',
#   'OT Losses': '9',
#   'Win %': '0.585',
#   'Goals For (GF)': '248',
#   'Goals Against (GA)': '213',
#   '+ / -': '35'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '2010',
#   'Wins': '38',
#   'Losses': '33',
#   'OT Losses': '11',
#   'Win %': '0.463',
#   'Goals For (GF)': '240',
#   'Goals Against (GA)': '234',
#   '+ / -': '6'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '2010',
#   'Wins': '46',
#   'Losses': '25',
#   'OT Losses': '11',
#   'Win %': '0.561',
#   'Goals For (GF)': '247',
#   'Goals Against (GA)': '240',
#   '+ / -': '7'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '2010',
#   'Wins': '37',
#   'Losses': '34',
#   'OT Losses': '11',
#   'Win %': '0.451',
#   'Goals For (GF)': '218',
#   'Goals Against (GA)': '251',
#   '+ / -': '-33'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '2010',
#   'Wins': '54',
#   'Losses': '19',
#   'OT Losses': '9',
#   'Win %': '0.659',
#   'Goals For (GF)': '262',
#   'Goals Against (GA)': '185',
#   '+ / -': '77'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '2010',
#   'Wins': '48',
#   'Losses': '23',
#   'OT Losses': '11',
#   'Win %': '0.585',
#   'Goals For (GF)': '224',
#   'Goals Against (GA)': '197',
#   '+ / -': '27'},
#  {'Team Name': 'Anaheim Ducks',
#   'Year': '2011',
#   'Wins': '34',
#   'Losses': '36',
#   'OT Losses': '12',
#   'Win %': '0.415',
#   'Goals For (GF)': '204',
#   'Goals Against (GA)': '231',
#   '+ / -': '-27'},
#  {'Team Name': 'Boston Bruins',
#   'Year': '2011',
#   'Wins': '49',
#   'Losses': '29',
#   'OT Losses': '4',
#   'Win %': '0.598',
#   'Goals For (GF)': '269',
#   'Goals Against (GA)': '202',
#   '+ / -': '67'},
#  {'Team Name': 'Buffalo Sabres',
#   'Year': '2011',
#   'Wins': '39',
#   'Losses': '32',
#   'OT Losses': '11',
#   'Win %': '0.476',
#   'Goals For (GF)': '218',
#   'Goals Against (GA)': '230',
#   '+ / -': '-12'},
#  {'Team Name': 'Calgary Flames',
#   'Year': '2011',
#   'Wins': '37',
#   'Losses': '29',
#   'OT Losses': '16',
#   'Win %': '0.451',
#   'Goals For (GF)': '202',
#   'Goals Against (GA)': '226',
#   '+ / -': '-24'},
#  {'Team Name': 'Carolina Hurricanes',
#   'Year': '2011',
#   'Wins': '33',
#   'Losses': '33',
#   'OT Losses': '16',
#   'Win %': '0.402',
#   'Goals For (GF)': '213',
#   'Goals Against (GA)': '243',
#   '+ / -': '-30'},
#  {'Team Name': 'Columbus Blue Jackets',
#   'Year': '2011',
#   'Wins': '29',
#   'Losses': '46',
#   'OT Losses': '7',
#   'Win %': '0.354',
#   'Goals For (GF)': '202',
#   'Goals Against (GA)': '262',
#   '+ / -': '-60'},
#  {'Team Name': 'Chicago Blackhawks',
#   'Year': '2011',
#   'Wins': '45',
#   'Losses': '26',
#   'OT Losses': '11',
#   'Win %': '0.549',
#   'Goals For (GF)': '248',
#   'Goals Against (GA)': '238',
#   '+ / -': '10'},
#  {'Team Name': 'Colorado Avalanche',
#   'Year': '2011',
#   'Wins': '41',
#   'Losses': '35',
#   'OT Losses': '6',
#   'Win %': '0.5',
#   'Goals For (GF)': '208',
#   'Goals Against (GA)': '220',
#   '+ / -': '-12'},
#  {'Team Name': 'Dallas Stars',
#   'Year': '2011',
#   'Wins': '42',
#   'Losses': '35',
#   'OT Losses': '5',
#   'Win %': '0.512',
#   'Goals For (GF)': '211',
#   'Goals Against (GA)': '222',
#   '+ / -': '-11'},
#  {'Team Name': 'Detroit Red Wings',
#   'Year': '2011',
#   'Wins': '48',
#   'Losses': '28',
#   'OT Losses': '6',
#   'Win %': '0.585',
#   'Goals For (GF)': '248',
#   'Goals Against (GA)': '203',
#   '+ / -': '45'},
#  {'Team Name': 'Edmonton Oilers',
#   'Year': '2011',
#   'Wins': '32',
#   'Losses': '40',
#   'OT Losses': '10',
#   'Win %': '0.39',
#   'Goals For (GF)': '212',
#   'Goals Against (GA)': '239',
#   '+ / -': '-27'},
#  {'Team Name': 'Florida Panthers',
#   'Year': '2011',
#   'Wins': '38',
#   'Losses': '26',
#   'OT Losses': '18',
#   'Win %': '0.463',
#   'Goals For (GF)': '203',
#   'Goals Against (GA)': '227',
#   '+ / -': '-24'},
#  {'Team Name': 'Los Angeles Kings',
#   'Year': '2011',
#   'Wins': '40',
#   'Losses': '27',
#   'OT Losses': '15',
#   'Win %': '0.488',
#   'Goals For (GF)': '194',
#   'Goals Against (GA)': '179',
#   '+ / -': '15'},
#  {'Team Name': 'Minnesota Wild',
#   'Year': '2011',
#   'Wins': '35',
#   'Losses': '36',
#   'OT Losses': '11',
#   'Win %': '0.427',
#   'Goals For (GF)': '177',
#   'Goals Against (GA)': '226',
#   '+ / -': '-49'},
#  {'Team Name': 'Montreal Canadiens',
#   'Year': '2011',
#   'Wins': '31',
#   'Losses': '35',
#   'OT Losses': '16',
#   'Win %': '0.378',
#   'Goals For (GF)': '212',
#   'Goals Against (GA)': '226',
#   '+ / -': '-14'},
#  {'Team Name': 'Nashville Predators',
#   'Year': '2011',
#   'Wins': '48',
#   'Losses': '26',
#   'OT Losses': '8',
#   'Win %': '0.585',
#   'Goals For (GF)': '237',
#   'Goals Against (GA)': '210',
#   '+ / -': '27'},
#  {'Team Name': 'New Jersey Devils',
#   'Year': '2011',
#   'Wins': '48',
#   'Losses': '28',
#   'OT Losses': '6',
#   'Win %': '0.585',
#   'Goals For (GF)': '228',
#   'Goals Against (GA)': '209',
#   '+ / -': '19'},
#  {'Team Name': 'New York Islanders',
#   'Year': '2011',
#   'Wins': '34',
#   'Losses': '37',
#   'OT Losses': '11',
#   'Win %': '0.415',
#   'Goals For (GF)': '203',
#   'Goals Against (GA)': '255',
#   '+ / -': '-52'},
#  {'Team Name': 'New York Rangers',
#   'Year': '2011',
#   'Wins': '51',
#   'Losses': '24',
#   'OT Losses': '7',
#   'Win %': '0.622',
#   'Goals For (GF)': '226',
#   'Goals Against (GA)': '187',
#   '+ / -': '39'},
#  {'Team Name': 'Ottawa Senators',
#   'Year': '2011',
#   'Wins': '41',
#   'Losses': '31',
#   'OT Losses': '10',
#   'Win %': '0.5',
#   'Goals For (GF)': '249',
#   'Goals Against (GA)': '240',
#   '+ / -': '9'},
#  {'Team Name': 'Philadelphia Flyers',
#   'Year': '2011',
#   'Wins': '47',
#   'Losses': '26',
#   'OT Losses': '9',
#   'Win %': '0.573',
#   'Goals For (GF)': '264',
#   'Goals Against (GA)': '232',
#   '+ / -': '32'},
#  {'Team Name': 'Phoenix Coyotes',
#   'Year': '2011',
#   'Wins': '42',
#   'Losses': '27',
#   'OT Losses': '13',
#   'Win %': '0.512',
#   'Goals For (GF)': '216',
#   'Goals Against (GA)': '204',
#   '+ / -': '12'},
#  {'Team Name': 'Pittsburgh Penguins',
#   'Year': '2011',
#   'Wins': '51',
#   'Losses': '25',
#   'OT Losses': '6',
#   'Win %': '0.622',
#   'Goals For (GF)': '282',
#   'Goals Against (GA)': '221',
#   '+ / -': '61'},
#  {'Team Name': 'San Jose Sharks',
#   'Year': '2011',
#   'Wins': '43',
#   'Losses': '29',
#   'OT Losses': '10',
#   'Win %': '0.524',
#   'Goals For (GF)': '228',
#   'Goals Against (GA)': '210',
#   '+ / -': '18'},
#  {'Team Name': 'St. Louis Blues',
#   'Year': '2011',
#   'Wins': '49',
#   'Losses': '22',
#   'OT Losses': '11',
#   'Win %': '0.598',
#   'Goals For (GF)': '210',
#   'Goals Against (GA)': '165',
#   '+ / -': '45'},
#  {'Team Name': 'Tampa Bay Lightning',
#   'Year': '2011',
#   'Wins': '38',
#   'Losses': '36',
#   'OT Losses': '8',
#   'Win %': '0.463',
#   'Goals For (GF)': '235',
#   'Goals Against (GA)': '281',
#   '+ / -': '-46'},
#  {'Team Name': 'Toronto Maple Leafs',
#   'Year': '2011',
#   'Wins': '35',
#   'Losses': '37',
#   'OT Losses': '10',
#   'Win %': '0.427',
#   'Goals For (GF)': '231',
#   'Goals Against (GA)': '264',
#   '+ / -': '-33'},
#  {'Team Name': 'Vancouver Canucks',
#   'Year': '2011',
#   'Wins': '51',
#   'Losses': '22',
#   'OT Losses': '9',
#   'Win %': '0.622',
#   'Goals For (GF)': '249',
#   'Goals Against (GA)': '198',
#   '+ / -': '51'},
#  {'Team Name': 'Washington Capitals',
#   'Year': '2011',
#   'Wins': '42',
#   'Losses': '32',
#   'OT Losses': '8',
#   'Win %': '0.512',
#   'Goals For (GF)': '222',
#   'Goals Against (GA)': '230',
#   '+ / -': '-8'},
#  {'Team Name': 'Winnipeg Jets',
#   'Year': '2011',
#   'Wins': '37',
#   'Losses': '35',
#   'OT Losses': '10',
#   'Win %': '0.451',
#   'Goals For (GF)': '225',
#   'Goals Against (GA)': '246',
#   '+ / -': '-21'}]

# %%
with open('teams_data.json', 'w') as json_file:
    json.dump(teams_json, json_file, indent=4)
